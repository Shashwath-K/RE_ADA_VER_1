# %% [markdown]
# # #Leetcode - Q1
#
# Given an array of integers `nums` and an integer `target`, return indices of the two numbers such that they add up to `target`.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.

# %%
def calculateTwoSum(nums, target):
  n = len(nums)
  for i in range (n):
    for j in range(i+1 , n):
      if (nums[i]+nums[j] == target):
        return print ([i, j])
if __name__ == "__main__":
  nums = [2,1,11,7]
  target = 9
  calculateTwoSum(nums,target)
# Out:
# [0, 3]

# %% [markdown]
# ## String Methods
# Use of pre-defined string methods like `.upper()` , `.lower()`, `.capitalize()` and `.swapcase()`

# %%
str2 = 'DOEs'
print(f"Uppercase : {str2.upper()}\nLowercase: {str2.lower()}\nCapitalize: {str2.capitalize()}\nSwapCases :{str2.swapcase()}")
# Out:
# Uppercase : DOES
# Lowercase: does
# Capitalize: Does
# SwapCases :doeS

# %% [markdown]
# # Use Looping statements to enter student `n` number of student details.

# %%
n = int(input('Enter the number of students: '))
arr1 = []
for i in range(n):
    student_name = input("\nEnter the student name: ")
    age = int(input("Enter the Age: "))
    phone_number = int(input("Enter the phone number:"))
    city = input("Enter City: ")
    arr1.append([student_name,age,phone_number,city])
print(arr1)
# Out:
# Enter the number of students: 3
# Enter the student name: student1
# Enter the Age: 22
# Enter the phone number:9393537475747
# Enter City: Delhi
# Enter the student name: student2
# Enter the Age: 23
# Enter the phone number:9575748374774
# Enter City: Mysore
# Enter the student name: student3
# Enter the Age: 24
# Enter the phone number:9574738738747
# Enter City: Uganda
# [['student1', 22, 9393537475747, 'Delhi'], ['student2', 23, 9575748374774, 'Mysore'], ['student3', 24, 9574738738747, 'Uganda']]

# %% [markdown]
# # Sort the files to directories based on extensions
# Steps:
# - Input `file_name`
# - Finds the last occuring `.<extension_name>`
# - Store the `.<extension_name>` in a variable.
# - Move files to the categorized directory using if-else statements.

# %%
file_inp = input("Enter file name: ")
fin=file_inp.rfind(".")
file_type=file_inp[fin:]
if(file_type == ".pdf"):
  print(f"moving file type {file_type} to Docs")
elif(file_type == ".jpg"):
  print(f"Moving file type {file_type} to Images")
else:
  print(f"Invalid file type {file_type} Moving to others")
# Out:
# Enter file name: Shaan.jpg
# Moving file type .jpg to Images

# %%
file_input = input("Enter the file name: ")
file_ext = {
  ".pdf":{"type": "document","name": "Portable document format", },
  ".docx":{"type": "document","name": "Word document", },
  ".xlsx":{"type": "document","name": "Excel Spreadsheet", },
  ".txt":{"type": "document","name": "Plain text file", },

  ".png":{"type": "image","name": "portable network graphics", },
  ".jpeg":{"type": "image","name": "Joint Photographic experts group", },

  ".ipynb":{"type": "code","name": "Python notebook", },
  ".py":{"type": "code","name": "Python program", },
  }
file_extension = file_input[(file_input.rfind(".")):]
if(file_ext[file_extension]["type"] == "document"):
  print(f"moving file type {file_input} of type {file_extension} to Docs")
elif(file_ext[file_extension]["type"] == "image"):
  print(f"Moving file type {file_input} of type {file_extension} to Images")
elif(file_ext[file_extension]["type"] == "code"):
  print(f"Moving file type {file_input} of type {file_extension} to Programs")
else:
  print(f"Invalid file type {file_input} of type {file_extension} Moving to others")
# Out:
# Moving file type movie.png of type .png to Images

# %% [markdown]
# # Washing Machine problem
# A washing machine works on the principle of `Fuzzy System`, the weight of the clothes put inside it for washing is uncertain. But based on weight measured by sensors, it decides time and water level which can be changed by menus given on the machine control area.
#
# > For **low level** water, the time estimate is `25 minutes`, where approximately weight is between `2000` grams or any nonzero positive number below that.
#
# > For **medium level** water, the time estimate is `35 minutes`, where approximately weight is between `2001` grams and `4000` grams.
#
# > For **high level** water, the time estimate is `45 minutes`, where approximately weight is between `4000` grams and `7000` grams.
#
# Assume the capacity of the machine is maximum `7000` grams.
# Where approximately weight is zero, time estimate is 0 minutes.

# %%
cloth_weight = float(input("Enter the Weight of the clothes: "))
if (cloth_weight > 0):
  if(cloth_weight<2000):
    print(f"For the {cloth_weight}, Requires low level of water, Estimated time of wash is 25 mins")
  elif(cloth_weight >= 2000 and cloth_weight<4000):
    print(f"For the {cloth_weight}, Requires Medium Water level. Estimated time of wash is 35 mins")
  elif(cloth_weight>= 4000 and cloth_weight<7000):
    print(f"For the {cloth_weight}, Requires High level of water. Estimated time of wash is 45 mins")
  else:
    print(f"{cloth_weight} Weight Overload!")
else:
  print(f"The Weight is {cloth_weight} Est. time is 0 minutes")
# Out:
# Enter the Weight of the clothes: 1
# For the 1.0, Requires low level of water, Estimated time of wash is 25 mins

# %% [markdown]
# Using `in-range`

# %%
cloth_weight = float(input("Enter the Weight of the clothes: "))
if cloth_weight > 0:
  if cloth_weight in range(1,2000):
    print(f"For the {cloth_weight}, Requires low level of water, Estimated time of wash is 25 mins")
  elif cloth_weight in range(2000,4000):
    print(f"For the {cloth_weight}, Requires med level of water, Estimated time of wash is 35 mins")
  elif cloth_weight in range(4000,7000):
    print(f"For the {cloth_weight}, Requires high level of water, Estimated time of wash is 45 mins")
  else:
    print(f"{cloth_weight} weight overloaded!")
else:
  print(f"For the {cloth_weight}, Estimated time of wash is 0 mins")
# Out:
# Enter the Weight of the clothes: 09000
# 9000.0 weight overloaded!

# %% [markdown]
# # Employee Performance Rating System
# *Using condtional statements*
#
# ### Problem Scenario (HR Automation Case Study):
#
# A multinational company is automating its annual employee appraisal process. Each employee receives a perfoemance score between 0 an 100, based on multiple evaluation parameters like teamwork, communication, KPI achievements and innovation. The HR wants an automated system (Python-based) that takes `employee name` and `score` as input and outputs.
#
#
# | Score Range  | Rating         | Appraisal Eligibility          |
# |--------------|----------------|--------------------------------|
# | 90-100 | Outstanding | Eligible for high appraisal|
# | 75-89 | Excellent | Eligible for moderate appraisal|
# | 60-74 | Good | Eligible for basic appraisal|
# | 40-59 | Needs Improvement | Not Eligible |
# | Below 40 | Poor | Not Eligible & training Required |

# %%
name_var = input("Enter the employee name : ")
score_var = int(input("Enter the score of the employee: "))
print(f"-------------------------------\nEmployee {name_var} has a score : {score_var}")
if(score_var > 0 and score_var<101):
  if score_var in range(40,59):
    print(f"Rating : Needs Improvement,\nAppraisal Status:  Not eligible")
  elif score_var in range(60,74):
    print(f"Rating : Good, \nAppraisal Status:  Eligible for Basic Appraisal")
  elif score_var in range(75,89):
    print(f"Rating : Excellent, \nAppraisal Status:  Eligible for Moderate Appraisal")
  elif score_var in range(90,101):
    print(f"Rating : Outstanding, \nAppraisal Status:  Eligible for High Appraisal\nConsidered for leadership and International opportunities")
  else:
    print(f"Rating : Poor, \nAppraisal Status:  Not eligible & training required")
else:
  print("Invalid input")
# Out:
# Enter the employee name : Yogi
# Enter the score of the employee: 45
# ----------------------------
# Employee Yogi has a score : 45
# Rating : Needs Improvement,
# Appraisal Status:  Not eligible

# %% [markdown]
# ## Scenario Based Problem - Fuel Efficiency indicator
#
# A leading automobile conpany is developing a Python-based tool to analyze vehicle fuel efficiency. A remote IoT sensor collects the `distance travelled (km)` and `fuel consumed (litres)` after each trip. Based on the `fuel economy (km/l)`, the system must classify the vehicle's efficiency and provide suggestions.
#
# Inputs:
# - Take `distance (km)` and `fuel used (litres)` as input.
# - Calculate `fuel efficiency` using:
#   - Fuel Efficiency = Distance /Fuel used.
#
# | Efficiency | Category | Suggested Action |
# |------------|----------|------------------|
# | >=20 | Excellent | Optimal engine performance |
# | 15-19 | Good | No action needed |
# |10 -14 | Needs Maintenance| Tune Engine required|
# |<10 | Critical | Immediate inspection |

# %%
vechicle_id = input("Enter Vehicle ID (Ex: TN12AB0010) : ")
distance_travelled = float(input("Enter Distance (km) : "))
fuel_used = float(input("Fuel used (litres) :"))
fuel_efficiency = distance_travelled/fuel_used
print(f"----------------------------------------\nFuel Efficiency Report\n----------------------------------------\nVehicle: {vechicle_id}\nDistance Travelled : {distance_travelled} km\nFuel used : {fuel_used} liters\nEfficiency : {round(fuel_efficiency,2)} km/l")
if (fuel_efficiency >=20):
  print(f"Efficiency Category : 🚀Excellent\nSuggested Action: Engine performance optimal. No action required ")
elif(fuel_efficiency in range(15,20)):
  print(f"Efficiency Category : Good\nSuggested Action: No action needed ")
elif(fuel_efficiency in range(10,15)):
  print(f"Efficiency Category : Needs Maintenance\nSuggested Action:Tune Engine required")
elif(fuel_efficiency in range(0,10)):
  print(f"Efficiency Category : Critical\nSuggested Action: Immediate inspection ")
else:
  print("Efficiency Category : Invalid \nSuggested Action: <Re-enter details> ")
print("----------------------------------------")
# Out:
# Enter Vehicle ID (Ex: TN12AB0010) : KA21AP1234
# Enter Distance (km) : 1000
# Fuel used (litres) :3
# ----------------------------------------
# Fuel Efficiency Report
# ----------------------------------------
# Vehicle: KA21AP1234
# Distance Travelled : 1000.0 km
# Fuel used : 3.0 liters
# Efficiency : 333.33 km/l
# Efficiency Category : 🚀Excellent
# Suggested Action: Engine performance optimal. No action required
# ----------------------------------------

# %% [markdown]
# ### Python Data Structures
#
#
# #### Strings
# - Strings can be copied using two methods like `Shallow copy` and `Deep Copy`
# - A collection of characters
# - Strings are `immutable` sequence.
#
# ``` python
#         a = "Welcome to Strings"
#         print(a[1])
#         print(a[8])
#         print(a[11])
# ```
#
# - `Indexing`  : Positive and Negative indexing
# - `Slicing`   : Has `2` types of slicing `Starting` and `Ending`
#    - Syntax : string_name[ Start, End, Step ]
#
#     ``` python
#         print(a[:-2]) #Output : Welcome to Strin
#     ```
#
#     ``` python
#         print(a[-2:]) #Output : gs
#     ```
# - `Substrings` : To get the part of a string
#     ``` python
#         print(a[1:4]) #Output : elc
#     ```
#     ``` python
#         print(a[1:8]) #Output : elcome t
#     ```
#     ``` python
#         print(a[1:-3]) #Output : elcome t
#     ```
# - `Reverse a String` : [ (Start and end is empty) step is given to negative value]
#     ``` python
#         print(a[::-1]) #Output :  sgnirtS ot emocleW
#         a = "Hello world"
#         print(a[::-2]) #Output :  drWolH
#         print(a[::-5]) #Output :  d H
#         print(a[::2])  #Output :  HloWrd
#         print(a[2::])  #Output :  llo World
#         print(a[-2::]) #Output :  ld
#         print(a[0:11:2]) #Output : Hlowrd
#     ```
#
#
# #### String Functions
#
# - `strip()` : To remove blank spaces from `start (also lstrip)` and `end (also rstrip)`.
# - `lower()` : Converts the string to lowercase.
# - `replace()` : Replace the character or set of characters with a new value.
# - `split()`   : Splits the character into multiple strings based on the character or criteria which will be stored and represented in a list.
# - `count()`  : Returns the number of times the string is repeated.
# - `index()`  : Returns the Index value of the first occurence of a character.
#     ``` python
#         print(a.index("l")) # Returns the first index of l.
#     ```
# - `capitalize()` : Converts first character of sequential string to Uppercase and rest to lowercase.
# - `find()` :  Similar to index which returns the index value else if not present/found returns -1.
#
# #### List
# - Collection of Multiple data
# - Holds Multiple datatypes
# - Lists are `Mutable`
# - Store multiple data at same time.
#
# - **Creating a List**
#   - *Note* :
#      ``` python
#          num = [1,2,3,4]
#          a, *other = num # Which assigns the first element,
#          # in this case num[0] = 1 to a (a = 10) and *other will have the rest of the list in `type: LIST`
#      ```
#   - list(range(1,11)) : Prints from the range starting from 1 to 11.
#   - List methods:
#     - append()
#     - copy()
#     - count()
#     - insert()
#     - reverse()
#     - remove()
#     - sort()
#     - pop()
#     - extend()
#     - index()
#     - clear()
#
# #### Python Tuples

# %% [markdown]
# > Dated : 5/12/2025
# ### Second family of Python DS
#
# #### Python Dictionary:
#
# - Stores values in key-value pairs.
# - values can be duplicated, but not keys.
# - Keys are case sensitive, different cases of key names are treated distinctly.
# - Duplicate keys will overwrite the previous value.
# - Internally uses hashing
#
# - Methods
#   - `.get()` : will retrive the value by specifying the key.
#   - `del()`  : Removes an item by key
#   - `pop()`  : Removes an item by key and returns it's value
#   - `clear()`: Empties the dictionary
#   - `popitem()`: Removes an returns the last key-value pair.
#
#
# > for-loops iterations
#
# - for key in d: # Iterate over keys
# - for value in d.values(): # Iterate over values
# - for key, value in d.items(): # Iterate over key and values pairs

# %%
a = 8
print(type(a))

a = []
a.append([1, [2, 3], 4])
a.extend([7, 8, 9])
print(a[0][1][1] + a[2])
print('''String, type's Have "I quotes" ''')


d = dict() 
for x in enumerate(range(2)): 
	d[x[0]] = x[1] 
	d[x[1]+7] = x[0] 
print(d)

tup1 = (1, 2, 4, 3) 
tup2 = (1, 2, 3, 4) 
print(tup1 < tup2)
# Out:
# <class 'int'>
# 11
# String, type's Have "I quotes"
# {0: 0, 7: 0, 1: 1, 8: 1}

# %% [markdown]
# > Note: Write about sets
#
# ##### Date : 9/12/2025
#
# ### Python Functions
#
# - Group of related statements that perform a specific task.
# - Helps to break problems into chunks
# - Avoids repeatition and make code re-usable.
#
# ``` bash
# functions types : user-defined, pre-defined, anonymous functions.
# ```
#
# **Problem : Find Factorial of a number**

# %%
n = int(input("Enter the number"))
fact = 1
if n == 0 or n ==1:
    print(fact)
else:
    for i in range(1,n+1):
        fact = fact *i
print(f"Factorial of {n} is {fact}")
# Out:
# Factorial of 5 is 120

# %%
def factorial_num(fact,num):
    if num == 0:
        return fact
    else:
        return factorial_num(fact*num, num-1)

if __name__ == "__main__":
    num = int(input("Enter the number"))
    res = factorial_num(1,num)
    print(f"Factorial of {num} is {res}")
# Out:
# Factorial of 5 is 120

# %%
import math
if __name__ == "__main__":
    num = int(input("Enter the number"))
    res = math.factorial(num)
    print(f"Factorial of {n} is {res}")
# Out:
# Factorial of 5 is 120

# %% [markdown]
# Types to write functions:
#
# With or Without:
#  - Arguments
#  - Return type
#
# Types of Functions : <Refer up>
#
# Anonymous function : Defined using the keyword `lambda`
#
# ### Lambda functions
#
# - Lambda forms can take any number of arguments but returns only one value in the form of expression.
# - They cannot contain `commands` or `multiple expressions`
# - Any anonymous function cannot be a directly call to print because it requires lambda expression.
#
# **Syntax**
#
# *lambda parameter_1,parameter_2,...parameter_n*
#
# Mappping to get multiple inputs ` map() `

# %%
sum1 = lambda x, y,z,a,b,c : x * y + z // a * b - c 
print(sum1(2,3,3,4,1,2))

x = int(input("1 "))
y = int(input("2 "))
sum2 = lambda x,y : x+y
print(sum2(x,y))
# Out:
# 4
# 6

# %% [markdown]
# ### Scope of variables
#
# - Local variable
# - Global variable

# %%
def chooseOperation(choice):
  x = float(input("Enter 1st number : "))
  y = float(input("Enter 2nd number : "))
  if(choice == "1"):
      return x + y
  elif(choice == "2"):
      return x - y
  elif(choice == "3"):
      return x * y
  elif(choice == "4"):
      try :
          return x / y
      except :
          print("Cannot divide number by 0")
  elif(choice == "5"):
      return x % y

choice = 0
while(choice != "0"):
  print(f"Arithmetic Chatbot for University Helpdesk\n{"-"*20}\n1.Addition\n2.Subtraction\n3.Multiplication\n4.Division\n5.Modulus\n0.Exit\n{"-"*20}")
  choice = input("Enter your choice : ")
  if choice == "0":
      break
  print(f"{chooseOperation(choice)}\n")
# Out:
# Arithmetic Chatbot for University Helpdesk
# --------------------
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Modulus
# 0.Exit
# --------------------
# 34.0
#
# Arithmetic Chatbot for University Helpdesk
# --------------------
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Modulus
# 0.Exit
# --------------------

# %%
import math
def distanceCovered(x,y):
    res = math.sqrt((x[1]-x[0])**2 + (y[1]-y[0])**2)
    return res
print(f"{"*"*50}\nDistance calculator for campus security robot\n{"*"*50}\n")
x = [0]*2
y = [0]*2
for i in range(2):
    x[i] = int(input(f"Enter x{[i+1]} :"))
    y[i] = int(input(f"Enter y{[i+1]} :"))
print(f"Distance covered: {distanceCovered(x,y)}")
# Out:
# **************************************************
# Distance calculator for campus security robot
# **************************************************
#
# 0 0
# 3 4
# Distance covered: 5.0

# %%
def eligibilityCheck(student_details):
    for i in range(len(student_details)):
        if student_details[i]["Marks"]>=85 and student_details[i]["Attendance"]>=75 and student_details[i]["Participation"]>=50:
            return "Eligible"
        else:
            return "Not Eligible"
print(f"{"*"*50}\nStudent Scholarship eligibility Checker\n{"*"*50}\n")
student_details = {}
num = int(input("Enter the Number of candidates: "))
for i in range(num):
    marks = int(input(f'Enter marks of student {i+1}'))
    attendance = int(input(f'Enter attendance of student {i+1} in %'))
    participation = int(input(f'Enter participation of student {i+1}'))
    student_details[i] = {"Marks":marks,"Attendance":attendance,"Participation":participation}
print(f"Stuent is {eligibilityCheck(student_details)} for scholarship")
# Out:
# **************************************************
# Student Scholarship eligibility Checker
# **************************************************
#
# Stuent is Eligible for scholarship

# %%
def billSplitter(n,t):
    res = t // n
    return res
if __name__ == "__main__":
    print(f"{"*"*50}\nHostel Mess bill splitter\n{"*"*50}\n")
    num_students = int(input("Enter number of students: "))
    total_amount = int(input("Enter total amount :")) 
    print(f"{billSplitter(num_students,total_amount)} per student")
# Out:
# **************************************************
# Hostel Mess bill splitter
# **************************************************
#
# 900 per student

# %%
def codeGen(name, dept, phone):
    initials = name[(name.rindex(" "))+1]
    ph_tkn = phone[(len(phone)-4):]
    return (f"{name[0]}{initials}_{dept}_{ph_tkn}")
if __name__ == "__main__":
    print(f"{"*"*50}\nCourse Registration Token generator\n{"*"*50}\n")
    name = input("Enter name : ")
    dept = input("Enter Department : ")
    phn  = input("Enter phone number : ")
    print(f"Generated code : {codeGen(name,dept,phn)}")
# Out:
# **************************************************
# Course Registration Token generator
# **************************************************
#
# Generated code : AK_AI_3210

# %%
def candidateSelection(candidates):
    if candidates["Score"] > 90:
        return "Elite"
    elif candidates["Score"] in range(75,90):
        return "Proficient"
    elif candidates["Score"] in range(50,75):
        return "Average"
    else:
        return "Needs Improvement"

if __name__ == "__main__":
    print(f"{"*"*50}\nTeam Selection Based on Performance Score\n{"*"*50}\n")
    num = int(input("Enter the number of candidates: "))
    candidates = {}
    for i in range(num):
        name = input("Enter name : ")
        perform_score = int(input("Enter performance score : "))
        candidates[i] = {"Name": name, "Score": perform_score}
        print(f"{candidates[i]["Name"]} : {candidateSelection(candidates[i])}")
# Out:
# **************************************************
# Team Selection Based on Performance Score
# **************************************************
#
# Rahul : Elite
# Maya : Proficient

# %%
def analyzeTransaction(bal, withdrawl):
    if withdrawl<=bal:
        print(f"Transaction successful -> New Balance : {bal-withdrawl}")
    else:
        print("Insufficient funds")
if __name__ == "__main__":
    print(f"{"*"*50}\nATM Mini Simulator for Banking Lab\n{"*"*50}\n")
    balance = int(input("Enter Balance : "))
    withdrawl = int(input("Enter the amount to be withdrawed : "))
    analyzeTransaction(balance,withdrawl)
# Out:
# **************************************************
# ATM Mini Simulator for Banking Lab
# **************************************************
#
# Transaction successful -> New Balance : 1500

# %%
def calculateFine(num):
    if num == 0:
        return "No fine"
    return num*5
if __name__ == "__main__":
    print(f"{"*"*50}\nLibrary Fine Calculator\n{"*"*50}\n")
    num = int(input("Enter the number of days the book is overdue : "))
    print(f"Overdue days : {num} -> Penalty : {calculateFine(num)}")
# Out:
# **************************************************
# Library Fine Calculator
# **************************************************
#
# Overdue days : 0 -> Penalty : No fine

# %%
def calculateBMI(weight, height):
    bmi_res = round((int(weight)/float(height)**2),2)
    if bmi_res < 18.5:
        print(f"BMI = {bmi_res} (Underweight)")
    elif 18.5 <= bmi_res <= 24.9:
        print(f"BMI = {bmi_res} (Normal)")
    elif 25.0 <= bmi_res <= 29.9:
        print(f"BMI = {bmi_res} (Overweight)")
    elif bmi_res > 30:
        print(f"BMI = {bmi_res} (Obese)")
    else:
        print("Invalid")
if __name__ == "__main__":
    print(f"{"*"*50}\nBasic BMI Calculator for Health Club\n{"*"*50}\n")
    weight = input("Enter Weight : ")
    height = input("Enter Height : ")
    calculateBMI(weight, height)
# Out:
# **************************************************
# Basic BMI Calculator for Health Club
# **************************************************
#
# 37.11
# BMI = 37.11 (Obese)

# %%
import re
def verifyStudentId(student_id):
    re_pattern = re.compile(r'^[A-Z]{2}[0-9]{4}[A-Z][0-9]{3}$')
    if len(student_id) == 10 and re_pattern.match(student_id):
        print(f"ID : {student_id} is Valid")
    else:
        print(f"ID : {student_id} is Invalid")
if __name__ == "__main__":
    print(f"{"*"*50}\nSimple ID Verification System\n{"*"*50}\n")
    name = input("Enter name : ")
    student_id = input("Enter ID")
    verifyStudentId(student_id)
# Out:
# **************************************************
# Simple ID Verification System
# **************************************************
#
# ID : 123434 is Invalid

# %% [markdown]
# ## Dated 12/12/2025 Session 2 :
#
# #### Dictionaries vs Sets:
#
# ![image.png](attachment:image.png)
#
# #### Functions vs Recursions:
#
# ![image-2.png](attachment:image-2.png)
#
# ## py+lib
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %%
list1 = [12,3,5,2,4,5,6,1]
print(set(list1))
# Out:
# {1, 2, 3, 4, 5, 6, 12}

# %%
text_str = "Awesome PRODUCT!!! Loved it.. WIll BUY again & again"
no_punctuations = text_str.translate(str.maketrans('', '',",.!?@%^&*()"))
lower_text = no_punctuations.lower()
splitting = lower_text.split()
common_letters = (sorted(set(splitting)))
print(f"Total words : {len(splitting)}")
print(f"Unique words : {common_letters}")
# Out:
# Total words : 8
# Unique words : ['again', 'awesome', 'buy', 'it', 'loved', 'product', 'will']

# %%
if __name__ == "__main__":
    choice = 0
    patient_queue = []
    print(f"\nHospital Patient Queue System\n1.Add new patients\n2.Remove the first patient\n3.Show current queue\n4.Exit")
    while choice !=4:
        choice = int(input("Enter your choice : "))
        if len(patient_queue)!=10:
            if choice == 1:
                name = input("Enter patient name : ")
                patient_queue.append(name)
            elif choice == 2:
                patient_queue.remove(patient_queue[0])
            elif choice == 3:
                print(patient_queue)
            elif choice == 4:
                break
            else:
                print("Invalid choice")
        else:
            print("patient queue is full")
# Out:
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
# ['Meera', 'Kiran', 'Veeksha', 'Akash']
# Hospital Patient Queue System
# 1.Add new patients
# 2.Remove the first patient
# 3.Show current queue
# 4.Exit
