# %% [markdown]
# 83. Remove Duplicates from Sorted List
#
#
# Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.
#
# ``` bash
# Example 1:
#
# Input: head = [1,1,2]
# Output: [1,2]
#
# Example 2:
#
# Input: head = [1,1,2,3,3]
# Output: [1,2,3]

# %%
from typing import Optional
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        tempNode = head
        while head and head.next:
            if head.val == head.next.val:
                head.next = head.next.next
            else:
                head = head.next
            
        return tempNode

if __name__ == "__main__":
    head = [1,1,2,3,3]
    sol = Solution()
    print(sol.deleteDuplicates(head))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 21
#      19 head = [1,1,2,3,3]
#      20 sol = Solution()
# ---> 21 print(sol.deleteDuplicates(head))
#
# Cell In[17], line 10, in Solution.deleteDuplicates(self, head)
#       8 def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
#       9     tempNode = head
# ---> 10     while head and head.next:
#      11         if head.val == head.next.val:
#      12             head.next = head.next.next
#
# AttributeError: 'list' object has no attribute 'next'
