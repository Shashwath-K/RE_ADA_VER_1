# %% [markdown]
# # Find k largest elements in an array
#
# Given an array arr[] and an integer k, the task is to find k largest elements in the given array. Elements in the output array should be in decreasing order.

# %% [markdown]
# **Examples:**
# ``` bash
# Input:  [1, 23, 12, 9, 30, 2, 50], k = 3
# Output: [50, 30, 23]
#
# Input:  [11, 5, 12, 9, 44, 17, 2], k = 2
# Output: [44, 17]
# ```

# %%
def findKLargest(arr, k):
    arr.sort(reverse=True)
    print(f"The {k} largest elements are: ", arr[:k])
if __name__ == "__main__":
    arr = [1, 23, 12 , 9, 30, 2, 50]
    print("the Original array :", arr)
    findKLargest(arr, 3)
# Out:
# the Original array : [1, 23, 12, 9, 30, 2, 50]
# The 3 largest elements are:  [50, 30, 23]
