# %% [markdown]
# > Dated : 28/03/2026
#
# # AI-12 Python Introduction Class
#
# Abbrevations -> Q: Question, D: Discussion
#
# Q: Why should we learn Python?
# D: Problems with AI? (Blind Usages)
# - Halluciantion
# - Math intensive Calculation
# - Long context - Catastrophic memory loss.
# - Complicate - un-necessary complexity of the code.
# - Images and videos.
# - Security and Privacy.
# - Cut-off on training.
# - Debugging challenges.
#
# Q: Do you understand the Code generated by AI?
# - Integration challenges.

# %%
# Out:
# 35
