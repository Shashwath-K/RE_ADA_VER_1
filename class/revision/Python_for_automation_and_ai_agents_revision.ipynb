# %% [markdown]
# > Revision for SEE
# # Python Essentials for automation and AI Agents
#
# #### What is Python?
# A: Python is a high-level, interpreted, Object oriented programming language created by Guido van Rossum in 1991. It is known for it's simplicity, readability, cross-platform support and extensive libraries.
# - Widely used in automation, artificial intelligence, data science and web development.
# - Python supports procedural, object oriented and functional programming.
#
# #### Data types and variables
# A: Variables store the data and are dyncamically typed.
# Python variable rules:
# - Cannot start with a digit.
# - No special characters except _ (underscore)
# - Case-Sensitive
#
# ### Python Keywords
# - Keywords are reserved words in python.
# - In python, keywords are case sensitive.
#
# In the below print statement you can see that there's 35 keywords in python 3.14.
#
# #### Identify Python Keywords
# *Ways to identify Python Keywords are:*
#
# - With Syntax Highlighting: Keywords appearing in different color or style.
# - Look for SyntaxError: This error will encounter if you have used any keyword incorrectly.
#
# | Category                  | Keywords                                                                 |
# |---------------------------|--------------------------------------------------------------------------|
# | Value Keywords            | True, False, None                                                        |
# | Operator Keywords         | and, or, not, is, in                                                      |
# | Control Flow Keywords     | if, else, elif, for, while, break, continue, pass, try, except, finally, raise, assert |
# | Function and Class        | def, return, lambda, yield, class                                        |
# | Context Management        | with, as                                                                 |
# | Import and Module         | import, from                                                             |
# | Scope and Namespace       | global, nonlocal                                                         |
# | Async Programming         | async, await                                                             |

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Question : Why is it risky to use keywords as variable names in automation scripts?
#
# A: Using Keywords as variable names in automation scripts is risky because these words have special meanings in programming langiuages, which can lead to compilation errors or unexpected behaviour in the code. This can make the script difficult to debug and maintain.

# %% [markdown]
# <h2>Python Operators</h2>
#
# > In Python programming, Operators in general are used to perform operations on values and variables.
#
# - Operators: Special symbols like -, + , * , /, etc.
# - Operands: Value on which the operator is applied.
#
# | Type                   | Operators                     |
# |------------------------|-------------------------------|
# | Arithmetic Operators   | +, -, *, /, %                 |
# | Relational Operators   | <, <=, >, >=, ==, !=, <>      |
# | Logical Operators      | AND, OR, NOT                  |
# | Bitwise Operator       | &, 'l', '^', '~', '<<', '>>'  |
# | Assignment Operator    | =, +=, -=, *=, %=             |

# %%
a=1
for i in range(20):
    print(a, end=' ')
    a+=a
print("\n")
print("0,0,1,0,0,1,1"
# Out:
# 1 2 4 8 16 32 64 128 256 512 1024 2048 4096 8192 16384 32768 65536 131072 262144 524288
#
# 0,0,1,0,0,1,1
# 102400

# %%
# Example for Comparison/Relational operators
a = 13
b = 33

print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)

# %% [markdown]
# <h5>Logical Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > Python Logical operators perform Logical AND, Logical OR and Logical NOT operations. It is used to combine conditional statements.
#
# The precedence of Logical Operators in Python is as follows:
#
# 1. Logical not
# 2. logical and
# 3. logical or

# %%
# Example for Logical operators
a = True
b = False
print(a and b)
print(a or b)
print(not a)

# %% [markdown]
# <h5>Bitwise Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > Python Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers.
#
# Bitwise Operators in Python are as follows:
#
# 1. Bitwise NOT
# 2. Bitwise Shift
# 3. Bitwise AND
# 4. Bitwise XOR
# 5. Bitwise OR

# %%
# Example for the Bitwise operators
a = 10
b = 4

print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)

# %% [markdown]
# <h5>Assignment Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > Python Assignment operators are used to assign values to the variables. This operator is used to assign the value of the right side of the expression to the left side operand.
#
#
# | Operator | Description                   |
# |----------|-------------------------------|
# | =        | Assignment                    |
# | /=       | Divide and assign             |
# | +=       | Add and assign                |
# | -=       | Subtract and assign           |
# | *=       | Multiply and assign           |
# | %=       | Modulus and assign            |
# | **=      | Exponent and assign           |
# | //=      | Floor division and assign     |

# %%
# Example for Assignment operators
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# <h5>Identical Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > In Python, is and is not are the identity operators both are used to check if two values are located on the same part of the memory. Two variables that are equal do not imply that they are identical.
#
# ``` python
# is          # True if the operands are identical
# is not      # True if the operands are not identical
# ```

# %%
# Example for Identity operators
a = 10
b = 20
c = a

print(a is not b)
print(a is c)

# %% [markdown]
# <h5>Membership Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > In Python, in and not in are the membership operators that are used to test whether a value or variable is in a sequence.
# ``` python
# in            # True if value is found in the sequence
# not in        # True if value is not found in the sequence
# ```

# %%
# Example for Membership Operators
x = 24
y = 20
list = [10, 20, 30, 40, 50]

if (x not in list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")

if (y in list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")

# %% [markdown]
# <h5>Ternary Operators</h5>
# <details>
# <summary>Show more</summary>
#
# > in Python, Ternary operators also known as conditional expressions are operators that evaluate something based on a condition being true or false. It was added to Python in version 2.5.
#
# *It simply allows testing a condition in a single line replacing the multiline if-else, making the code compact.*
#
# > Syntax :  [on_true] if [expression] else [on_false]

# %%
a, b = 10, 20
min = a if a < b else b

print(min)

# %% [markdown]
# <h2>Comment Lines</h2>
# <details>
# <summary>Show more</summary>
#
# Comments are used to explain code and make it easier to understand. Python ignores comments when executing the program.
#
#
# #### 1. Single-Line Comments
#
# Single-line comments start with the `#` symbol.
#
# ```python
# # This is a single-line comment
# x = 10  # This comment explains the variable
# ```
#
# #### 2. Multi-Line Comments
#
# Python does not have a dedicated multi-line comment syntax. However, multi-line comments can be written using multiple # symbols.
#
# ``` python
# # This is a multi-line comment
# # written using multiple
# # single-line comments
# ```
#
# #### 3. Docstrings (Documentation Strings)
#
# Docstrings are used to document functions, classes, or modules. They are written using triple quotes (''' or """).
#
# ``` py
# def add(a, b):
#     """
#     This function adds two numbers
#     and returns the result.
#     """
#     return a + b
# ```

# %% [markdown]
# <h2>Conditional Statements in Python</h2>
#
# - Conditional statements in Python are used to execute certain blocks of code based on specific conditions.
# - These statements help control the flow of a program, making it behave differently in different situations.
#
# <h5>If Conditional Statement</h5>
# <details>
# <summary>Show more</summary>
# If statement is the simplest form of a conditional statement. It executes a block of code if the given condition is true.
#
# **Syntax**
# ``` python
# if condition:
#     # body of if statement
# ```
# Here, `condition` is a boolean expression, such as number > 5, that evaluates to either ```True``` or ```False```.
#
# - If `condition` evaluates to `True`, the body of the if statement is executed.
# - If `condition` evaluates to `False`, the body of the if statement will be skipped from execution.
#
# #### Working of if statement:
# ![image.png](attachment:image.png)

# %%
# Example program for the if statement
number = int(input('Enter a number: '))

# check if number is greater than 0
if number > 0:
    print(f'{number} is a positive number.')

print('A statement outside the if statement.')

# %% [markdown]
# <h5>Python if...else statement</h5>
# <details>
# <summary>Show more</summary>
#
# An `if` statement can have an optional `else` clause. The `else` statement executes `if` the condition in the if statement evaluates to `False`.
#
# **Syntax**
# ``` python
# if condition:
#     # body of if statement
# else:
#     # body of else statement
# ```
# Here, if the condition inside the if statement evaluates to
#
# - **True** - the body of if executes, and the body of else is skipped.
# - **False** - the body of else executes, and the body of if is skipped
#
# **Example:**
# ![image.png](attachment:image.png)

# %%
# Example for if-else statement:
number = int(input('Enter a number: '))

if number > 0:
    print('Positive number')
else:
    print('Not a positive number')

print('This statement always executes')

# %% [markdown]
# <h5>Python if...elif...else statement</h5>
# <details>
# <summary>Show more</summary>
#
# The `if...else` statement is used to execute a block of code among two alternatives.
#
# However, if we need to make a choice between more than two alternatives, we use the `if...elif...else` statement.
#
# **Syntax**
# ``` python
# if condition1:
#     # code block 1
#
# elif condition2:
#     # code block 2
#
# else:
#     # code block 3
# ```
# **Example:**
# ![image.png](attachment:image.png)

# %%
# Example for Python if-elif-else statement:
number = -5

if number > 0:
    print('Positive number')

elif number < 0:
    print('Negative number')

else:
    print('Zero')

print('This statement is always executed')

# %% [markdown]
# <h5>Python Nested if statement</h5>
# <details>
# <summary>Show more</summary>
#
# **Nested if..else** means an if-else statement inside another if statement. We can use nested if statements to check conditions within conditions.
#
# **Example:**
# ![image.png](attachment:image.png)

# %%
# Example for Nested if...else statement:
number = 5

# outer if statement
if number >= 0:
    # inner if statement
    if number == 0:
      print('Number is 0')
    
    # inner else statement
    else:
        print('Number is positive')

# outer else statement
else:
    print('Number is negative')

# %% [markdown]
# <h5>Ternary Conditional Satement</h5>
# <details>
# <summary>Show more</summary>
#
# A ternary conditional statement is a compact way to write an if-else condition in a single line. It’s sometimes called a `conditional expression.`

# %%
# Assign a value based on a condition
age = 20
s = "Adult" if age >= 18 else "Minor"
print(s)

# %% [markdown]
# <h5>Match-Case Satement</h5>
# <details>
# <summary>Show more</summary>
#
# `match-case statement` is Python's version of a switch-case found in other languages. It allows us to match a variable's value against a set of patterns.

# %%
number = 2

match number:
    case 1:
        print("One")
    case 2 | 3:
        print("Two or Three")
    case _:
        print("Other number")

# %% [markdown]
# <h3>Class Exercise - 1</h3>
# <h4>Sort the files to directories based on extensions</h4>
# <details>
# <summary>Show more</summary>
#
# **Steps:**
# - Input `file_name`
# - Finds the last occuring `.<extension_name>`
# - Store the `.<extension_name>` in a variable.
# - Move files to the categorized directory using if-else statements.

# %%
# Solution #1 
file_input = input("Enter file name: ")
extension=file_input.rfind(".")
file_type=file_input[extension:]
if(file_type == ".pdf"):
  print(f"moving file type {file_type} to Docs")
elif(file_type == ".jpg"):
  print(f"Moving file type {file_type} to Images")
else:
  print(f"Invalid file type {file_type} Moving to others")

# %%
# Solution #2 using dictionaries
file_input = input("Enter the file name: ")
file_ext = {
  ".pdf":{"type": "document","name": "Portable document format", },
  ".docx":{"type": "document","name": "Word document", },
  ".xlsx":{"type": "document","name": "Excel Spreadsheet", },
  ".txt":{"type": "document","name": "Plain text file", },

  ".png":{"type": "image","name": "portable network graphics", },
  ".jpeg":{"type": "image","name": "Joint Photographic experts group", },

  ".ipynb":{"type": "code","name": "Python notebook", },
  ".py":{"type": "code","name": "Python program", },
  }
file_extension = file_input[(file_input.rfind(".")):]
if(file_ext[file_extension]["type"] == "document"):
  print(f"moving file type {file_input} of type {file_extension} to Docs")
elif(file_ext[file_extension]["type"] == "image"):
  print(f"Moving file type {file_input} of type {file_extension} to Images")
elif(file_ext[file_extension]["type"] == "code"):
  print(f"Moving file type {file_input} of type {file_extension} to Programs")
else:
  print(f"Invalid file type {file_input} of type {file_extension} Moving to others")

# %% [markdown]
# <h3>Class Exercise - 2</h3>
# <h4>Washing Machine problem</h4>
# <details>
# <summary>Show more</summary>
#
# A washing machine works on the principle of `Fuzzy System`, the weight of the clothes put inside it for washing is uncertain. But based on weight measured by sensors, it decides time and water level which can be changed by menus given on the machine control area.
#
# > For **low level** water, the time estimate is `25 minutes`, where approximately weight is between `2000` grams or any nonzero positive number below that.
#
# > For **medium level** water, the time estimate is `35 minutes`, where approximately weight is between `2001` grams and `4000` grams.
#
# > For **high level** water, the time estimate is `45 minutes`, where approximately weight is between `4000` grams and `7000` grams.
#
# Assume the capacity of the machine is maximum `7000` grams.
# Where approximately weight is zero, time estimate is 0 minutes.

# %%
# Solution 1
cloth_weight = float(input("Enter the Weight of the clothes: "))
if (cloth_weight > 0):
  if(cloth_weight<2000):
    print(f"For the {cloth_weight}, Requires low level of water, Estimated time of wash is 25 mins")
  elif(cloth_weight >= 2000 and cloth_weight<4000):
    print(f"For the {cloth_weight}, Requires Medium Water level. Estimated time of wash is 35 mins")
  elif(cloth_weight>= 4000 and cloth_weight<7000):
    print(f"For the {cloth_weight}, Requires High level of water. Estimated time of wash is 45 mins")
  else:
    print(f"{cloth_weight} Weight Overload!")
else:
  print(f"The Weight is {cloth_weight} Est. time is 0 minutes")

# %%
# Solution 2 using in-range
cloth_weight = float(input("Enter the Weight of the clothes: "))
if cloth_weight > 0:
  if cloth_weight in range(1,2000):
    print(f"For the {cloth_weight}, Requires low level of water, Estimated time of wash is 25 mins")
  elif cloth_weight in range(2000,4000):
    print(f"For the {cloth_weight}, Requires med level of water, Estimated time of wash is 35 mins")
  elif cloth_weight in range(4000,7000):
    print(f"For the {cloth_weight}, Requires high level of water, Estimated time of wash is 45 mins")
  else:
    print(f"{cloth_weight} weight overloaded!")
else:
  print(f"For the {cloth_weight}, Estimated time of wash is 0 mins")

# %% [markdown]
# <h3>Class Exercise - 3</h3>
# <h4>Employee Performance Rating System</h4>
# <details>
# <summary>Show more</summary>
#
# *Using condtional statements*
#
# ### Problem Scenario (HR Automation Case Study):
#
# A multinational company is automating its annual employee appraisal process. Each employee receives a perfoemance score between 0 an 100, based on multiple evaluation parameters like teamwork, communication, KPI achievements and innovation. The HR wants an automated system (Python-based) that takes `employee name` and `score` as input and outputs.
#
#
# | Score Range  | Rating         | Appraisal Eligibility          |
# |--------------|----------------|--------------------------------|
# | 90-100 | Outstanding | Eligible for high appraisal|
# | 75-89 | Excellent | Eligible for moderate appraisal|
# | 60-74 | Good | Eligible for basic appraisal|
# | 40-59 | Needs Improvement | Not Eligible |
# | Below 40 | Poor | Not Eligible & training Required |

# %%
name_var = input("Enter the employee name : ")
score_var = int(input("Enter the score of the employee: "))
print(f"-------------------------------/nEmployee {name_var} has a score : {score_var}")
if(score_var > 0 and score_var<101):
  if score_var in range(40,59):
    print(f"Rating : Needs Improvement,/nAppraisal Status:  Not eligible")
  elif score_var in range(60,74):
    print(f"Rating : Good, /nAppraisal Status:  Eligible for Basic Appraisal")
  elif score_var in range(75,89):
    print(f"Rating : Excellent, /nAppraisal Status:  Eligible for Moderate Appraisal")
  elif score_var in range(90,101):
    print(f"Rating : Outstanding, /nAppraisal Status:  Eligible for High Appraisal/nConsidered for leadership and International opportunities")
  else:
    print(f"Rating : Poor, /nAppraisal Status:  Not eligible & training required")
else:
  print("Invalid input")

# %% [markdown]
# <h3>Class Exercise - 4</h3>
# <h4>Scenario Based Problem - Fuel Efficiency indicator</h4>
# <details>
# <summary>Show more</summary>
#
# A leading automobile conpany is developing a Python-based tool to analyze vehicle fuel efficiency. A remote IoT sensor collects the `distance travelled (km)` and `fuel consumed (litres)` after each trip. Based on the `fuel economy (km/l)`, the system must classify the vehicle's efficiency and provide suggestions.
#
# Inputs:
# - Take `distance (km)` and `fuel used (litres)` as input.
# - Calculate `fuel efficiency` using:
#   - Fuel Efficiency = Distance /Fuel used.
#
# | Efficiency | Category | Suggested Action |
# |------------|----------|------------------|
# | >=20 | Excellent | Optimal engine performance |
# | 15-19 | Good | No action needed |
# |10 -14 | Needs Maintenance| Tune Engine required|
# |<10 | Critical | Immediate inspection |

# %%
vechicle_id = input("Enter Vehicle ID (Ex: TN12AB0010) : ")  
distance_travelled = float(input("Enter Distance (km) : "))
fuel_used = float(input("Fuel used (litres) :"))
fuel_efficiency = distance_travelled/fuel_used
print(f"----------------------------------------/nFuel Efficiency Report/n----------------------------------------/nVehicle: {vechicle_id}/nDistance Travelled : {distance_travelled} km/nFuel used : {fuel_used} liters/nEfficiency : {round(fuel_efficiency,2)} km/l")
if (fuel_efficiency >=20):
  print(f"Efficiency Category : 🚀Excellent/nSuggested Action: Engine performance optimal. No action required ")
elif(fuel_efficiency in range(15,20)):
  print(f"Efficiency Category : Good/nSuggested Action: No action needed ")
elif(fuel_efficiency in range(10,15)):
  print(f"Efficiency Category : Needs Maintenance/nSuggested Action:Tune Engine required")
elif(fuel_efficiency in range(0,10)):
  print(f"Efficiency Category : Critical/nSuggested Action: Immediate inspection ")
else:
  print("Efficiency Category : Invalid /nSuggested Action: <Re-enter details> ")
print("----------------------------------------")

# %% [markdown]
# <h3>Looping Statements</h3>
# <h4>Python for-loops</h4>
# <details>
# <summary>Show more</summary>
#
# - A `for loop` is used for iterating over a sequence.
# - It is like an iterator method as found in other object-orientated programming languages.
#
# In Python, we use a `for loop` to iterate over sequences such as lists, strings, dictionaries, etc. For example:
#
# ``` python
# languages = ['Swift', 'Python', 'Go']
#
# # access elements of the list one by one
# for lang in languages:
#     print(lang)
# ```
#
# **Output**
# ``` bash
# Swift
# Python
# Go
# ```
#
#
#
# **for loop Syntax**
# ``` py
# for val in sequence:
#     # run this code
# ```
#
# The `for` loop iterates over the elements of sequence in order, and in each iteration, the body of the loop is executed.
#
# The loop ends after the body of the loop is executed for the last item.
#
#
#
# **Indentation in Loop**
#
# In Python, we use indentation (spaces at the beginning of a line) to define a block of code, such as the body of a loop.
#
#
#
#
# #### for Loop with Python range()
# In Python, the `range()` function returns a sequence of numbers.
#
# ``` py
# # generate numbers from 0 to 3
# values = range(0, 4)
# ```
#
#
#
# #### break and continue Statement
# The `break` and `continue` statements are used to alter the flow of loops.
#
# **The break Statement**
# The `break` statement terminates the for loop immediately before it loops through all the items. For example,
#
# ``` py
# languages = ['Swift', 'Python', 'Go', 'C++']
#
# for lang in languages:
#     if lang == 'Go':
#         break
#     print(lang)
#
# ```
#
# *Output:*
#
# ``` bash
# Swift
# Python
# ```
# Here, when `lang` is equal to `Go`, the `break` statement inside the `if` condition executes which terminates the loop immediately. This is why `Go` and `C++` are not printed.
#
#
#
#
#
# **The continue Statement**
#
# The continue statement skips the current iteration of the loop and continues with the next iteration. For example,
#
# ``` py
# languages = ['Swift', 'Python', 'Go', 'C++']
#
# for lang in languages:
#     if lang == 'Go':
#         continue
#     print(lang)
# ```
#
# *Output:*
#
# ``` bash
# Swift
# Python
# C++
# ```
# Here, when lang is equal to `Go`, the continue statement executes, which skips the remaining code inside the loop for that iteration.

# %%
# example for for-loop:
n = 4
for i in range(0, n):
    print(i)

# %% [markdown]
# <h4>Nested for-loops</h4>
# <details>
# <summary>Show more</summary>
#
# - A loop can also contain another loop inside it. These loops are called nested loops.
#
# - In a nested loop, the inner loop is executed once for each iteration of the outer loop.
#
# ``` py
# # outer loop
# attributes = ['Electric', 'Fast']
# cars = ['Tesla', 'Porsche', 'Mercedes']
#
# for attribute in attributes:
#     for car in cars:
#         print(attribute, car)
#
#     # this statement is outside the inner loop
#     print("-----")
# ```
#
# #### Using for loop without accessing sequence items
#
#
# If we don't intend to use items of sequence inside the body of a loop, it is clearer to use the `_` (underscore) as the loop variable. For example,
#
# ``` py
# # iterate from i = 0 to 3
# for _ in range(0, 4):
#     print('Hi')
# ```

# %%
# Example for nested for loop
n = 4
for i in range(0,n):
    for j in range(i,n):
        print(i,j, end="")

# %% [markdown]
# <h4>Python while loop</h4>
# <details>
# <summary>Show more</summary>
#
#
# - In Python, we use a while loop to repeat a block of code **until a certain condition is met**.
# - Once the condition is false, the control will come out of the loop.
#
# *Syntax*
#
# ```py
# while condition:
#     # body of while loop
# ```

# %%
# Example for while loop
# Print numbers until the user enters 0
number = int(input('Enter a number: '))

# iterate until the user enters 0
while number != 0:
    print(f'You entered {number}.')
    number = int(input('Enter a number: '))

print('The end.')

# %% [markdown]
# <h4>Infinite while loop</h4>
# <details>
# <summary>Show more</summary>
#
# If the condition of a while loop always evaluates to `True`, the loop runs continuously, forming an infinite while loop. For example,

# %%
# Example for infinite while-loop
age = 32

# The test condition is always True
while age > 18:
    print('You can vote')

# %% [markdown]
# <h2>Python break and continue</h2>
# <details>
# <summary>Show more</summary>
#
# In programming, the `break` and `continue` statements are used to alter the flow of loops:
#
# - **break** exits the loop entirely
#   - With the break statement we can stop the loop before it has looped through all the items.
#   - When break is encountered, the loop is exited and the lines after the loop is executed.
# - **continue** skips the current iteration and proceeds to the next one
#   - With the continue statement we can stop the current iteration of the loop, and continue with the next.
#   -  When continue is encountered, it skips the current iteration.

# %%
# Example for break statement
for i in range(1,6):  
    if(i==4): 
        print ("loop breaks") 
        break
print (i, end=" ")

# %%
# Example for continue statement
for i in range(1,6):   
    if(i==4): 
        print ("loop skips") 
        continue
    print (i, end=" ")
print()

# %% [markdown]
# <h2>Pass Statement</h2>
# <details>
# <summary>Show more</summary>
#
# In Python programming, the `pass` statement is a null statement which can be used as a placeholder for future code.
#
# Suppose we have a loop or a function that is not implemented yet, but we want to implement it in the future. In such cases, we can use the `pass` statement.

# %%
# Example for pass statement
def pass_example():
    pass                #defines an empty function without parameters or errors
print(pass_example)

# %% [markdown]
# <h2>Python Numbers, Type Coversion and Mathematics</h2>
# <h5>Types of numbers</h5>
# <details>
# <summary>Show more</summary>
#
# > The number data types are used to store the numeric values. Python supports integers, floating-point numbers and complex numbers.
#
# - `int` - holds signed integers of non-limited length.
# - `float` - holds floating decimal points and it's accurate up to 15 decimal places.
# - `complex` - holds complex numbers.
#
# Complex numbers are written in the form, `x + yj`, where `x` is the real part and `y` is the imaginary part.
#
# We can use the type() function to know which class a variable or a value belongs to.

# %%
num1 = 5
print(num1, 'is of type', type(num1))

num2 = 5.42
print(num2, 'is of type', type(num2))

num3 = 8+2j
print(num3, 'is of type', type(num3))

# %% [markdown]
# <h5>Number Systems</h5>
# <details>
# <summary>Show more</summary>
#
# - The numbers we deal with every day are of the decimal `(base 10)` number system.
#
# - But computer programmers need to work with binary `(base 2)`, hexadecimal `(base 16)` and octal `(base 8)` number systems.
#
# - In Python, we can represent these numbers by appropriately placing a prefix before that number. The following table lists these prefixes.
#
#
# |Number System |	Prefix|
# |--------------|----------|
# |Binary	|`0b` or `0B`|
# |Octal	|`0o` or `0O`|
# |Hexadecimal	|`0x` or `0X`|

# %%
# Example for Number systems
print(0b1101011)  # prints 107

print(0xFB + 0b10)  # prints 253

print(0o15)  # prints 13
# Out:
# 107
# 253
# 13
# 1

# %% [markdown]
# <h5>Type Conversion in Python</h5>
# <details>
# <summary>Show more</summary>
#
# In programming, type conversion is the process of converting one type of number into another.
#
# Operations like addition, subtraction **convert integers to float** implicitly (automatically), if one of the operands is float. For example,
#
# ``` py
# print(1 + 2.0) # prints 3.0
#
# ```
#
# #### Explicit Type Conversion
# We can also use built-in functions like int(), float() and complex() to convert between types explicitly. These functions can even convert from strings.

# %%
num1 = int(2.3)
print(num1)  # prints 2

num2 = int(-2.8)
print(num2)  # prints -2

num3 = float(5)
print(num3) # prints 5.0

num4 = complex('3+5j')
print(num4)  # prints (3 + 5j)

# %% [markdown]
# <h5>Python Random Module</h5>
# <details>
# <summary>Show more</summary>
#
# Python offers the `random` module to generate random numbers or to pick a random item from an iterator.
#
# First we need to import the `random` module.

# %%
# Example for the random module
import random
rand_smp = random.sample(range(1001), 5)
print(rand_smp)
print(random.randrange(10, 20))

list1 = ['a', 'b', 'c', 'd', 'e']

# get random item from list1
print(random.choice(list1))

# Shuffle list1
random.shuffle(list1)

# Print the shuffled list1
print(list1)

# Print random element
print(random.random())
# Out:
# [98, 815, 268, 701, 88]
# 16
# d
# ['b', 'e', 'a', 'd', 'c']
# 0.7806091479858103

# %% [markdown]
# <h5>Python Mathematics</h5>
# <details>
# <summary>Show more</summary>
#
# Python offers the math module to carry out different mathematics like trigonometry, logarithms, probability and statistics, etc.

# %%
# Example for python math modules
import math

print(math.pi)

print(math.cos(math.pi))

print(math.exp(10))

print(math.log10(1000))

print(math.sinh(1))

print(math.factorial(6))

# %%
# Example use of math module to find the area of a circle
import math
def calculate_area(radius):
    radius_res = math.pi*(radius**2)
    return radius_res

print(calculate_area(5))
# Out:
# 78.53981633974483

# %% [markdown]
# <h2>Python Strings</h2>
#
#
# In Python, a string is a sequence of characters. For example, "hello" is a string containing a sequence of characters 'h', 'e', 'l', 'l', and 'o'.
#
# We use single quotes or double quotes to represent a string in Python.
#
# #### Possible ways to create single-line strings
#
# ``` py
# # create a string using double quotes
# string1 = "Python programming"
#
# # create a string using single quotes
# string1 = 'Python programming'
# ```
#
# #### Multi-line Strings
# Use triple quotes ('''...''' ) or ( """...""") for strings that span multiple lines. Newlines are preserved.
#
# Example: Define and print multi-line strings using both styles.

# %%
s = """This is an example of 
Multi-line
Strings created using 3x the Double quotes."""
print(s)

s = '''Yes,
It can also be created 
using single quotes'''
print(s)
# Out:
# This is an example of
# Multi-line
# Strings created using 3x the Double quotes.
# Yes,
# It can also be created
# using single quotes

# %% [markdown]
# <h3>Accessing characters in String</h3>
# <details>
# <summary>Show more</summary>
#
# #### Strings are indexed sequences.
# - `Positive` indices start at `0` from the left.
# - `Negative` indices start at `-1` from the right.

# %% [markdown]
# <h5>String Slicing</h5>
# <details>
# <summary>Show more</summary>
#
# `Slicing` : Has `2` types of slicing `Starting` and `Ending`
#
#    - Syntax : string_name[ Start, End, Step ]
#
#     ``` python
#         print(a[:-2]) #Output : Welcome to Strin
#     ```
#
#     ``` python
#         print(a[-2:]) #Output : gs
#     ```
# - `Substrings` : To get the part of a string
#     ``` python
#         print(a[1:4]) #Output : elc
#     ```
#     ``` python
#         print(a[1:8]) #Output : elcome t
#     ```
#     ``` python
#         print(a[1:-3]) #Output : elcome t
#     ```
# - `Reverse a String` : [ (Start and end is empty) step is given to negative value]
#     ``` python
#         print(a[::-1]) #Output :  sgnirtS ot emocleW
#         a = "Hello world"
#         print(a[::-2]) #Output :  drWolH
#         print(a[::-5]) #Output :  d H
#         print(a[::2])  #Output :  HloWrd
#         print(a[2::])  #Output :  llo World
#         print(a[-2::]) #Output :  ld
#         print(a[0:11:2]) #Output : Hlowrd
#     ```

# %% [markdown]
# <h5>Python Strings are Immutable</h5>
# <details>
# <summary>Show more</summary>
#
# > In Python, strings are immutable. That means the characters of a string cannot be changed
#
# ``` py
# message = 'Hola Amigos'
# message[0] = 'H'
# print(message)
# ```
# <br/>
#
# > However, we can assign the variable name to a new string.
# ``` py
# message = 'Hola Amigos'
#
# # assign new string to message variable
# message = 'Hello Friends'
#
# print(message); # prints "Hello Friends"
# ```

# %% [markdown]
# <h3>Python String Methods</h3>
# <details>
# <summary>Show more</summary>
#
#
# - `strip()` : To remove blank spaces from `start (also lstrip)` and `end (also rstrip)`.
# - `lower()` : Converts the string to lowercase.
# - `len()`   : Returns the length of the string.
# - `startswith()` :	Checks if string starts with the specified string
# - `isnumeric()` :	Checks numeric characters
# - `replace()` : Replace the character or set of characters with a new value.
# - `split()`   : Splits the character into multiple strings based on the character or criteria which will be stored and represented in a list.
# - `count()`  : Returns the number of times the string is repeated.
# - `index()`  : Returns the Index value of the first occurence of a character.
#     ``` python
#         print(a.index("l")) # Returns the first index of l.
#     ```
# - `capitalize()` : Converts first character of sequential string to Uppercase and rest to lowercase.
# - `find()` :  Similar to index which returns the index value else if not present/found returns -1.

# %% [markdown]
# <h3>Python String Operations</h3>
# <details>
# <summary>Show more</summary>
#
# Many operations can be performed with strings, which makes it one of the most used data types in Python.
#
# 1. Compare Two Strings
# We use the `==` operator to compare two strings. If two strings are equal, the operator returns `True`. Otherwise, it returns `False`.
#
# ``` py
# str1 = "Hello, world!"
# str2 = "I love Swift."
# str3 = "Hello, world!"
#
# # compare str1 and str2
# print(str1 == str2)
#
# # compare str1 and str3
# print(str1 == str3)
# ```
# 2. Join Two or More Strings
# In Python, we can join (concatenate) two or more strings using the `+` operator.
#
# ``` py
# greet = "Hello, "
# name = "Jack"
#
# # using + operator
# result = greet + name
# print(result)
#
# # Output: Hello, Jack
# ```

# %% [markdown]
# <h3>Python String Interpolation</h3>
# <details>
# <summary>Show more</summary>
#
# String interpolation is a process **substituting values of variables into placeholders** in a string.
# <br/>
# For instance, if you have a template for saying hello to a person like "Hello {Name of person}, nice to meet you!", you would like to replace the placeholder for name of person with an actual name. This process is called string interpolation.
#
# 1.`f-strings`
# Python 3.6 added new string interpolation method called literal string interpolation and introduced a new literal prefix `f`. This new way of formatting strings is powerful and easy to use. It provides access to embedded Python expressions inside string constants.
#
# *Example:*
# ``` py
# name = 'World'
# program = 'Python'
# print(f'Hello {name}! This is {program}')
# ```
# When we run the above program, the output will be
#
# > Hello World! This is Python
#
#
# <br/>
#
# 2.`%-formatting`
# Strings in Python have a unique built-in operation that can be accessed with the `%` operator. Using `%` we can do simple string interpolation very easily.
#
# *Example:*
# ``` py
# print("%s %s" %('Hello','World',))
# ```
#
# When we run the above program, the output will be
#
# > Hello World
#
#
# <br/>
#
# 3.`Str.format()`
# In this string formatting we use `format()` function on a string object and braces {}, the string object in format() function is substituted in place of braces `{}`. We can use the format() function to do simple positional formatting, just like % formatting.
#
# *Example:*
#
# ``` py
# name = 'world'
# print('Hello, {}'.format(name))
# ```
#
# When we run the above program, the output will be
#
# > Hello,world
#
# <br/>
#
# 4.Template Strings
# Template Strings is simpler and less powerful mechanism of string interpolation. We need to `import Template` class from Python’s built-in `string` module to use it.
#
# *Example:*
#
# ``` py
# from string import Template
# name = 'world'
# program ='python'
# new = Template('Hello $name! This is $program.')
# print(new.substitute(name= name,program=program))
# ```
# When we run the above program, the output will be
#
# > Hello world! This is python.
#
# <br/>

# %% [markdown]
# <h2>Python List</h2>
# <details>
# <summary>Show more</summary>
#
# In Python, lists allow us to store multiple items in a single variable. For example, if you need to store the ages of all the students in a class, you can do this task using a list.
#
# Lists are similar to arrays (dynamic arrays that allow us to store items of different data types) in other programming languages.
#
# #### Summary
# - Collection of Multiple data
# - Holds Multiple datatypes
# - Lists are `Mutable`
# - Store multiple data at same time.
#
# - **Creating a List**
# -  1.  Using Square Brackets
#   ``` py
#     # a list of three elements
#     nums = [19, 26, 29]
#     print(nums)
#   ```
# - 2. Using list() Constructor
#   ``` py
#   a = list((1, 2, 3, 'apple', 4.5))
#   print(a)
#   ```
# - 3. Creating List with Repeated Elements
#   ``` py
#   a = [2] * 5
#   b = [0] * 7
#   ```
#   - *Note* :
#      ``` py
#          nums = [1,2,3,4]
#          a, *other = nums # Which assigns the first element,
#          # in this case num[0] = 1 to a (a = 10) and *other will have the rest of the list in `type: LIST`
#      ```

# %%
# Example of lists with different types
# a list containing strings, numbers and another list
student = ['Jack', 32, 'Computer Science', [2, 4]]
print(student)

# an empty list
empty_list = []
print(empty_list)

# %% [markdown]
# <h5>Python List -  Characteristics, Access Elements</h5>
# <details>
# <summary>Show more</summary>
#
# <h5>Characteristics</h5>
#
# **In Python, lists are:**
#
# - Ordered - They maintain the order of elements.
# - Mutable - Items can be changed after creation.
# - Allow duplicates - They can contain duplicate values.
#
#
# <h5>Access List Elements</h5>
#
# Each element in a list is associated with a number, known as an `index`. The index of first item is 0, the index of second item is 1, and so on.
#
# ``` py
# a = [10, 20, 30, 40, 50]
# print(a[0])
# print(a[-1])
# print(a[1:4])   # elements from index 1 to 3
# ```

# %%
# Accessing list elements
languages = ['Python', 'Swift', 'C++']

# access the first element
print('languages[0] =', languages[0])

# access the third element
print('languages[2] =', languages[2])

# %% [markdown]
# <h4>Python List - Adding Elements to List</h4>
# <details>
# <summary>Show more</summary>
#
# #### We can add elements to a list using the following methods:
#
# - append(): Adds an element at the end of the list.
# - extend(): Adds multiple elements to the end of the list.
# - insert(): Adds an element at a specific position.
# - clear(): removes all items.

# %%
# Example for adding list elements
a = []

a.append(10)  
print("After append:", a)  

a.insert(0, 5)
print("After insert:", a) 

a.extend([15, 20, 25])  
print("After extend:", a) 

a.clear()
print("After clear:", a)

# %% [markdown]
# <h4>Python List - Updating Elements into list</h4>
# <details>
# <summary>Show more</summary>
#
# Since lists are mutable, we can update elements by accessing them via their index.

# %%
a = [10, 20, 30, 40, 50]
a[1] = 25 
print(a)

# %% [markdown]
# <h4>Python List - Removing Elements from list</h4>
# <details>
# <summary>Show more</summary>
#
# #### Removing Elements from List
# We can remove elements from a list using:
#
# - remove(): Removes the first occurrence of an element.
# - pop(): Removes the element at a specific index or the last element if no index is specified.
# - del statement: Deletes an element at a specified index.

# %%
#Removing Elements from the list
a = [10, 20, 30, 40, 50]

a.remove(30)  
print("After remove(30):", a)

popped_val = a.pop(1)  
print("Popped element:", popped_val)
print("After pop(1):", a) 

del a[0]  
print("After del a[0]:", a)

# %% [markdown]
# <h4>Python List - Nested Lists</h4>
# <details>
# <summary>Show more</summary>
#
# A nested list is a list within another list, which is useful for representing matrices or tables. We can access nested elements by chaining indexes.

# %%
# Example for nested lists
matrix = [ [1, 2, 3],
           [4, 5, 6],
           [7, 8, 9] ]
print(matrix[1][2])

# %% [markdown]
# <h2>Python Tuple </h2>
# <details>
# <summary>Show more</summary>
#
# A tuple is a collection similar to a Python list. The primary difference is that we cannot modify a tuple once it is created.
#
# #### Create a Python Tuple
# We create a tuple by placing items inside parentheses (). For example,
#
# ``` py
# numbers = (1, 2, -5)
# print(numbers)
#
# # Output: (1, 2, -5)
# ```
#
# #### Create a tuple using tuple() constructor
#
# We can also create a tuple using a tuple() constructor. For example,
#
# ``` py
# tuple_constructor = tuple(('Jack', 'Maria', 'David'))
# print(tuple_constructor)
#
# # Output: ('Jack', 'Maria', 'David')
#
# ```

# %% [markdown]
# <h5>Different types of Python Tuples</h5>
# <details>
# <summary>Show more</summary>
#
# - Different Types of Python Tuples:
#   1. Empty Tuple:
#   ``` py
#     # create an empty tuple
#     empty_tuple = ()
#     print(empty_tuple)
#
#     # Output: ()
#   ```
#   2. Tuple of different data types:
#   ``` py
#   # tuple of string types
#     names = ('James', 'Jack', 'Eva')
#     print (names)
#
#     # tuple of float types
#     float_values = (1.2, 3.4, 2.1)
#     print(float_values)
#   ```
#   3. Tuple of mixed data types
#   ``` py
#   # tuple including string and integer
#     mixed_tuple = (2, 'Hello', 'Python')
#     print(mixed_tuple)
#
#     # Output: (2, 'Hello', 'Python')
#   ```

# %% [markdown]
# <h5>Characteristics Tuples</h5>
# <details>
# <summary>Show more</summary>
#
# Tuples are:
#
# - Ordered - They maintain the order of elements.
# - Immutable - They cannot be changed after creation.
# - Allow duplicates - They can contain duplicate values.

# %% [markdown]
# <h5>Access Tu[ple Items</h5>
# <details>
# <summary>Show more</summary>
#
# Each item in a tuple is associated with a number, known as a `index.`
#
# The index always starts from 0, meaning the first item of a tuple is at index 0, the second item is at index 1, and so on.
#
#
# #### Access Items Using Index
# We use index numbers to access tuple items. For example
#
# ``` py
# languages = ('Python', 'Swift', 'C++')
#
# # access the first item
# print(languages[0])   # Python
#
# # access the third item
# print(languages[2])   # C++
# ```

# %% [markdown]
# <h5>Tuple cannot be modified</h5>
# <details>
# <summary>Show more</summary>
#
# Python tuples are immutable (unchangeable). We cannot add, change, or delete items of a tuple.
#
# If we try to modify a tuple, we will get an error. For example
#
# ``` py
# cars = ('BMW', 'Tesla', 'Ford', 'Toyota')
#
# # trying to modify a tuple
# cars[0] = 'Nissan'    # error
#
# print(cars)
# ```

# %% [markdown]
# <h5>Python Tuple Methods</h5>
# <details>
# <summary>Show more</summary>
#
# In Python, tuples are immutables. Meaning, you cannot change items of a tuple once it is assigned. There are only two tuple methods count() and index() that a tuple object can call.
#
# - Python Tuple count() : returns count of the element in the tuple
# - Python Tuple index() : returns the index of the element in the tuple

# %% [markdown]
# <h2>Python Sets</h2>
# <details>
# <summary>Show more</summary>
#
# Python set is an `unordered` collection of multiple items having different datatypes.
# In Python, sets are `mutable`, unindexed and do not contain duplicates. The order of elements in a set is not preserved and can change.
#
# - Can store None values.
# - Implemented using hash tables internally.
# - Do not implement interfaces like Serializable or Cloneable.
# - Python sets are not inherently thread-safe; synchronization is needed if used across threads.

# %% [markdown]
# <h5>Create a set in python</h5>
# <details>
# <summary>Show more</summary>
#
# ### Using {}:
#
# In Python, we create sets by placing all the elements inside curly braces `{}`, separated by commas.
#
# A set can have any number of items and they may be of different types (integer, float, tuple, string, etc.). But a set cannot have mutable elements like lists, sets or dictionaries as its elements.
#
# ``` py
# # create a set of integer type
# student_id = {112, 114, 116, 118, 115}
# print('Student ID:', student_id)
#
# # create a set of string type
# vowel_letters = {'a', 'e', 'i', 'o', 'u'}
# print('Vowel Letters:', vowel_letters)
#
# # create a set of mixed data types
# mixed_set = {'Hello', 101, -2, 'Bye'}
# print('Set of mixed data types:', mixed_set)
# ```
#
# ### Using set() function:
#
# Python Sets can be created by using the built-in `set()` function with an iterable object or a sequence by placing the sequence inside curly braces, separated by a 'comma'.
#
# ``` py
# set1 = set()
# print(set1)
#
# set1 = set("GeeksForGeeks")
# print(set1)
#
# # Creating a Set with the use of a List
# set1 = set(["Geeks", "For", "Geeks"])
# print(set1)
#
# # Creating a Set with the use of a tuple
# tup = ("Geeks", "for", "Geeks")
# print(set(tup))
#
# # Creating a Set with the use of a dictionary
# d = {"Geeks": 1, "for": 2, "Geeks": 3}
# print(set(d))
#
# ```

# %% [markdown]
# <h5>Adding elements in a set in python</h5>
# <details>
# <summary>Show more</summary>
#
#
# ### Adding Elements to a Set in Python
# We can add items to a set using add() method and update() method. add() method can be used to add only a single item. To add multiple items we use update() method.
#
# ``` py
# # Creating a set
# set1 = {1, 2, 3}
#
# # Add one item
# set1.add(4)                 #Now : {1,2,3,4}
#
# # Add multiple items
# set1.update([5, 6])         #Now : {1,2,3,4,5,6}
#
# print(set1)

# %% [markdown]
# <h5>Accessing set in python</h5>
# <details>
# <summary>Show more</summary>
#
# We can loop through a set to access set items as set is unindexed and do not support accessing elements by indexing. Also we can use in keyword which is membership operator to check if an item exists in a set.
#
# ``` py
# set1 = set(["Reva", "For", "Excellence."])
#
# # Accessing element using For loop
# for i in set1:
#     print(i, end=" ")
#
# # Checking the element# using in keyword
# print("Reva" in set1)

# %% [markdown]
# <h5>Removing elements from set in python</h5>
# <details>
# <summary>Show more</summary>
#
#
# We can remove an element from a set in Python using several methods: remove(), discard() and pop(). Each method works slightly differently :
#
# - Using remove() Method or discard() Method
# - Using pop() Method
# - Using clear() Method
#
# ###  Using Remove method
# ``` py
# # Using Remove Method
# set1 = {1, 2, 3, 4, 5}
# set1.remove(3)
# print(set1)
#
# # Attempting to remove an element that does not exist
# try:
#     set1.remove(10)
# except KeyError as e:
#     print("Error:", e)
#
# # Using discard() Method
# set1.discard(4)
# print(set1)
#
# # Attempting to discard an element that does not exist
# set1.discard(10)  # No error raised
# print(set1)
# ```
#
#
# ### Using `pop()` Method:
#
# `pop()` method removes and returns an arbitrary element from the set. This means we don't know which element will be removed. If the set is empty, it raises a KeyError.
#
#
# ``` py
# set1 = {1, 2, 3, 4, 5}
# val = set1.pop()
# print(val)
# print(set1)
#
# # Using pop on an empty set
# set1.clear()  # Clear the set to make it empty
# try:
#     set1.pop()
# except KeyError as e:
#     print("Error:", e)
#
# ```
#
# <br/>
#
# ### Using clear() Method
# `clear()` method removes all elements from the set, leaving it empty.
# ``` py
# set1 = {1, 2, 3, 4, 5}
# set1.clear()
# print(set1)
# ```

# %% [markdown]
# <h5>Frozen Sets in Python</h5>
# <details>
# <summary>Show more</summary>
#
# A `frozenset` in Python is a built-in data type that is similar to a set but with one key difference that is immutability. This means that once a frozenset is created, we cannot modify its elements that is we cannot add, remove or change any items in it. Like regular sets, a frozenset cannot contain duplicate elements.
#
# If no parameters are passed, it returns an empty frozenset.
# ``` py
# # Creating a frozenset from a list
# fset = frozenset([1, 2, 3, 4, 5])
# print(fset)
#
# # Creating a frozenset from a set
# set1 = {3, 1, 4, 1, 5}
# fset = frozenset(set1)
# print(fset)
# ```

# %% [markdown]
# <h5>Set Operations</h5>
# <details>
# <summary>Show more</summary>
#
# 1.Union of Two Sets
# The union of two sets A and B includes all the elements of sets A and B.
#
# ``` py
# # first set
# A = {1, 3, 5}
#
# # second set
# B = {0, 2, 4}
#
# # perform union operation using |
# print('Union using |:', A | B)
#
# # perform union operation using union()
# print('Union using union():', A.union(B))
#
# ```
#
# <br/>
#
#
# 2.Set Intersection
# The intersection of two sets A and B include the common elements between set A and B.
#
# ``` py
# # first set
# A = {1, 3, 5}
#
# # second set
# B = {1, 2, 3}
#
# # perform intersection operation using &
# print('Intersection using &:', A & B)
#
# # perform intersection operation using intersection()
# print('Intersection using intersection():', A.intersection(B))
#
# ```
#
# <br/>
#
# 3.Difference between Two Sets
# The difference between two sets A and B include elements of set A that are not present on set B.
#
# ``` py
# # first set
# A = {2, 3, 5}
#
# # second set
# B = {1, 2, 6}
#
# # perform difference operation using &
# print('Difference using &:', A - B)
#
# # perform difference operation using difference()
# print('Difference using difference():', A.difference(B))
# ```
#
# <br/>
#
# 4.Set Symmetric Difference
# The symmetric difference between two sets A and B includes all elements of A and B without the common elements.
#
# ``` py
# # first set
# A = {2, 3, 5}
#
# # second set
# B = {1, 2, 6}
#
# # perform difference operation using &
# print('using ^:', A ^ B)
#
# # using symmetric_difference()
# print('using symmetric_difference():', A.symmetric_difference(B))
# ```
#
# <br/>
#
# 5.Check if two sets are equal
# We can use the == operator to check whether two sets are equal or not.
#
# ``` py
#
# # first set
# A = {1, 3, 5}
#
# # second set
# B = {3, 5, 1}
#
# # perform difference operation using &
# if A == B:
#     print('Set A and Set B are equal')
# else:
#     print('Set A and Set B are not equal')
#
# ```
# <br/>

# %% [markdown]
# <h5>Python Set Methods</h5>
# <details>
# <summary>Show more</summary>
#
# | Method                         | Description                                                                 |
# |--------------------------------|-----------------------------------------------------------------------------|
# | add()                          | Adds an element to the set                                                   |
# | clear()                        | Removes all elements from the set                                            |
# | copy()                         | Returns a copy of the set                                                    |
# | difference()                   | Returns the difference of two or more sets as a new set                     |
# | difference_update()            | Removes all elements of another set from this set                           |
# | discard()                      | Removes an element from the set if it is a member (does nothing if not)     |
# | intersection()                 | Returns the intersection of two sets as a new set                           |
# | intersection_update()          | Updates the set with the intersection of itself and another                |
# | isdisjoint()                   | Returns True if two sets have a null intersection                           |
# | issubset()                     | Returns True if another set contains this set                               |
# | issuperset()                   | Returns True if this set contains another set                               |
# | pop()                          | Removes and returns an arbitrary set element; raises KeyError if empty      |
# | remove()                       | Removes an element from the set; raises KeyError if not found               |
# | symmetric_difference()         | Returns the symmetric difference of two sets as a new set                  |
# | symmetric_difference_update()  | Updates the set with the symmetric difference of itself and another        |
# | union()                        | Returns the union of sets as a new set                                      |
# | update()                       | Updates the set with the union of itself and others                         |

# %% [markdown]
# <h2>Python Dictionaries</h2>
# <details>
# <summary>Show more</summary>
#
# A Python dictionary is a collection of items, similar to lists and tuples. However, unlike lists and tuples, each item in a dictionary is a `key-value` pair (consisting of a key and a value).
#
# - Keys are case sensitive which means same name but different cases of Key will be treated distinctly.
# - Keys must be immutable which means keys can be strings, numbers or tuples but not lists.
# - Duplicate keys are not allowed and any duplicate key will overwrite the previous value.
# - Internally uses hashing. Hence, operations like search, insert, delete can be performed in Constant Time.

# %% [markdown]
# <h5>Creating a Dictionary</h5>
# <details>
# <summary>Show more</summary>
#
# Dictionary can be created by placing a sequence of elements within curly {} braces, separated by a `'comma'`.
#
#
# ``` py
# # creating a dictionary
# country_capitals = {
#   "Germany": "Berlin",
#   "Canada": "Ottawa",
#   "England": "London"
# }
#
# # printing the dictionary
# print(country_capitals)
#
# ```

# %% [markdown]
# <h5>Accessing Items in a Dictionary</h5>
# <details>
# <summary>Show more</summary>
#
# We can access a value from a dictionary by using the `key` within square brackets or `get()` method.
#
# ``` py
# d = { "name": "Prajjwal", 1: "Python", (1, 2): [1,2,4] }
#
# # Access using key
# print(d["name"])
#
# # Access using get()
# print(d.get("name"))
# ```

# %% [markdown]
# <h5>Adding and updating Dictionary items</h5>
# <details>
# <summary>Show more</summary>
#
# We can add new key-value pairs or update existing keys by using assignment.
#
# ``` py
# d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
#
# # Adding a new key-value pair
# d["age"] = 22
#
# # Updating an existing value
# d[1] = "Python dict"
#
# print(d)
# ```

# %% [markdown]
# <h5>Removing items in a Dictionary</h5>
# <details>
# <summary>Show more</summary>
#
# We can remove items from dictionary using the following methods:
#
# - del: Removes an item by key.
# - pop(): Removes an item by key and returns its value.
# - clear(): Empties the dictionary.
# - popitem(): Removes and returns the last key-value pair.
#
# ``` py
# d = {1: 'Byte', 2: 'code', 3: 'W#Schools', 'age':23}
#
# # Using del to remove an item
# del d["age"]
# print(d)
#
# # Using pop() to remove an item and return the value
# val = d.pop(1)
# print(val)
#
# # Using popitem to removes and returns
# # the last key
# key= d.popitem()
# print(f"Key: {key}")
#
# # Using popitem to removes and returns
# # the last key-value pair.
#
# key, value= d.popitem()
# print(f"Key: {key}, Value: {value}")
#
# # Clear all items from the dictionary
# d.clear()
# print(d)
#
# ```

# %% [markdown]
# <h5>Iterating Through a Dictionary</h5>
# <details>
# <summary>Show more</summary>
#
# We can iterate over keys [using keys() method] , values [using values() method] or both [using item() method] with a for loop.
#
# ``` py
# d = {1: 'Byte', 2: 'code', 'age':23}
#
# # Iterate over keys
# for key in d:
#     print(key)
#
# # Iterate over values
# for value in d.values():
#     print(value)
#
# # Iterate over key-value pairs
# for key, value in d.items():
#     print(f"{key}: {value}")
#
# ```

# %% [markdown]
# <h2>Python Functions</h2>
# <details>
# <summary>Show more</summary>
#
# - Group of related statements that perform a specific task.
# - Helps to break problems into chunks
# - Avoids repeatition and make code re-usable.
#
# ``` bash
# functions types : user-defined, pre-defined, anonymous functions.
# ```
#
# **Problem : Find Factorial of a number**

# %%
def fun1(name, age=20):
    print(name, age)

fun1('Emma', 25)
# Out:
# Emma 25

# %% [markdown]
# # Important Notes:
# ## String
# - A string in python is a sequence of Unicode characters (immutable)
# - Enclosed within `''`, `""` or `"""` , `'''`.
#
# ### Operations:
# - Indexing can be either of positive or negative indexing.
# - Slicing syntax (s[start:end:step])
# - Concatenation
# - Repetation
# - Membership
# - Length
# - Comparison
#
# ### List of Methods:
#   > Case Conversion:
#   - s.upper()
#   - s.lower()
#   - s.title()
#   - s.capitalize()
#   - s.swapcase()

# %%
print(f"{'-'*5} While")
# Out:
# ----- While

# %%
# Arithmetic chatbot for university Helpdesk

def arithmeticCall(operator_input):
    var_1 = int(input("Enter the first number: "))
    var_2 = int(input("Enter the second number: "))
    if operator_input == 1:
        result = var_1+var_2
    elif operator_input == 2:
        result = var_1-var_2
    elif operator_input == 3:
        result = var_1*var_2
    elif operator_input == 4:
        result = var_1//var_2
    elif operator_input == 5:
        return
    else:
        print("Invalid input: Exiting program")
        return
    print(result)
if __name__ =="__main__":
    print("Welcome to University Arithmetic Chatbot")
    operator_input = 0
    while(operator_input!=5):
        print(f"{'-'*5}Select and operation{'-'*5}")
        print(f"1.Add\t2.Subtract\t3.Multiply\t4.Divide\t5.Exit")
        operator_input = int(input("Operator : "))        
        arithmeticCall(operator_input)
# Out:
# Welcome to University Arithmetic Chatbot
# -----Select and operation-----
# 1.Add	2.Subtract	3.Multiply	4.Divide	5.Exit

# %%
# Euclidean distance calculator
import math
def euclidCalculator(x1,x2,y1,y2):
    distance = math.sqrt((x2-x1)**2+(y2-y1)**2)
    print(distance)
if __name__ == "__main__":
    x1,x2 = 1,4
    y1,y2 = 2,6
    euclidCalculator(x1,x2,y1,y2)
# Out:
# 5.0

# %%
# Student scholarship checker
def eligibilityCheck(marks,attendance,participation):
    if marks>=85:
        if attendance>=75:
            if participation>=50:
                return "Eligible"
    return "Ineligible"
if __name__ == "__main__":
    marks = int(input("Enter marks : "))
    attendance = int(input("Enter attendance percentage : "))
    participation = int(input("Enter participaion percentage : "))
    result = eligibilityCheck(marks,attendance,participation)
    print(result)
# Out:
# Eligible

# %%
#Hotel mess splitter

def billSplitter(total_amount, total_students):
    result = total_amount//total_students
    print(result)
if __name__ == "__main__":
    total_amount = int(input("Enter total amount : "))
    total_students = int(input("Enter total students : "))
    billSplitter(total_amount,total_students)
# Out:
# 900

# %%
# Course registration token generator

def tokenGenerator(name,department,ph_num):
    if len(name.split())>1:
        name_token = str.upper(name[0]+(name[name.rfind(' ')+1]))
    else:
        name_token = str.upper(name[:2])
    dept_token = str.upper(department[:2])
    phone_token = str(ph_num)[-4:]
    print(f"{name_token}_{dept_token}_{phone_token}")

if __name__ == "__main__":
    name = input("Enter Student name : ")
    department = input("Enter department")
    phone_number = int(input("Enter phone number : "))
    tokenGenerator(name,department,phone_number)
# Out:
# AK_AI_4353

# %%
# Team selection based on performance score

def teamSelection(score_result):
    if score_result == "Elite" or score_result == "Proficient":
        print("Team Selected")
    elif score_result == "Average":
        print("On Hold")
    else:
        print("Not selected")
def scorer(score):
    if score >=90:
        return "Elite"
    elif score in range(75,90):
        return "Proficient"
    elif score in range(50,75):
        return "Average"
    elif score <=50:
        return "Needs improvement"
    else:
        return "Invalid Score"
if __name__ == "__main__":
    name = input("Enter name : ")
    score = int(input("Enter the score : "))
    score_result = scorer(score)
    teamSelection_result = teamSelection(score_result)
# Out:
# On Hold

# %%
# ATM Mini Simulator

def BalanceChecker(balance, withdraw_amount):
    if withdraw_amount > balance:
        return "Insufficient funds"
    if balance <= 0:
        return "No minimum balance"
    else:
        new_balance = balance-withdraw_amount
        return new_balance

if __name__ == "__main__":
    balance = int(input("Enter balance : "))
    withdraw_amount = int(input("Enter the money to withdraw : "))
    result = BalanceChecker(balance,withdraw_amount)
    print(result)
# Out:
# Insufficient funds

# %%
# Library fine calculator

def fineCalculator(days_overdue):
    overdue_amount = days_overdue*5
    if overdue_amount == 0:
        return "No Fine"
    else:
        return overdue_amount

if __name__ == "__main__":
    print(f"{'-'*5}Library fine calculator{'-'*5}")
    days_overdue= int(input("Number of days overdue : "))
    amount = fineCalculator(days_overdue)
    print(amount)
# Out:
# -----Library fine calculator-----
# No Fine

# %%
# Basic BMI Calculator
def basicBMI(weight, height):
    bmi_score = weight/(height**2)
    print(bmi_score)
    if bmi_score < 18.5:
        return "UnderWeight"
    elif 18.5 <= bmi_score <= 24.9:
        return "Normal"
    elif 25 <= bmi_score <=29.9:
        return "Overweight"
    else:
        return "Obese"

if __name__ == "__main__":
    weight = float(input("Enter the weight in (kgs) : "))
    height = float(input("Enter height in (m) : "))
    result = basicBMI(weight,height)
    print(result)
# Out:
# 20.761245674740486
# Normal

# %%
# Simple ID verification

import re

def checkFormat(id_token):
    pattern_id = re.compile(r'^[a-zA-Z]{2}[0-9]{4}[a-zA-Z]{1}[0-9]{3}$')
    if pattern_id.match(id_token):
        return "Valid"
    else:
        return "Invalid"

if __name__ == "__main__":
    id_token = input("Enter the ID : ")
    result = checkFormat(id_token)
    print(result)
# Out:
# Valid

# %%
# Automated Hostel Attendance Checker

def attendanceCheck(total_class,class_attended,med_leave):
    total_attendance = (class_attended+med_leave)*100/total_class
    print(total_attendance)
    if total_attendance >= 75:
        return "Eligible"
    else:
        return "Ineligible"

if __name__ == "__main__":
    total_class = 120
    class_attended = 85
    med_leave = 5
    result = attendanceCheck(total_class, class_attended, med_leave)
    print(result)
# Out:
# 75.0
# Eligible

# %%
# Cafeteria purchase validator

def purchaseItem(available_balance,select_items,qty,cost):
    if available_balance >= cost*qty:
        return "Purchase successful"
    else:
        return "Insufficient balance"

if __name__ == "__main__":
    print(f"{'-'*5}Cafeteria purchase validator{'-'*5}")
    menu_items = {"Tea":10,"Sandwich":40}
    print(f"{'-'*5}Menu Items{'-'*5}")
    print("Item-------Price")
    for k,v in menu_items.items():
        print(f"{k}{'-'*5}{v}")
    available_balance = int(input("Enter available balance: "))
    select_items = input("Enter the order : ")
    qty = int(input("Enter the qty : "))
    cost = menu_items[select_items]
    purchase = purchaseItem(available_balance,select_items,qty,cost)
    if purchase == "Purchase successful":
        print(f"Item {select_items}{cost}, Qty = {qty}, total = {qty*cost}. Purchase Successful. Remaining balance = {available_balance-qty*cost}")
    else:
        print("Insufficient balance")
# Out:
# -----Cafeteria purchase validator-----
# -----Menu Items-----
# Item-------Price
# Tea-----10
# Sandwich-----40
# Item Sandwich40, Qty = 2, total = 80. Purchase Successful. Remaining balance = 20

# %%
# University bus allocation System

def assign_bus(route, time):
    buses = {
        "morning": {1:"Bus A1",2:"Bus A2",3:"Bus A3",4:"Bus B1",5:"Bus B2"},
        "evening": {1:"Bus C1",2:"Bus C2",3:"Bus C3"}
    }
    time = time.lower()
    if time in buses:
        if route in buses[time]:
            print(buses[time][route])
        else:
            print("Invalid Route")
    else:
        print("Invalid Time")

r = int(input())
t = input()
assign_bus(r, t)
# Out:
# Bus A2

# %%
# String error message analyzer
def errorAnalyzer(error_message):
    error_message = error_message.lower()
    if "error" in error_message:
        return "Critical"
    elif "failed" in error_message:
        return "Moderate"
    elif "warning" in error_message:
        return "Informational"
    else:
        return "Unknown"
if __name__ == "__main__":
    error_message = input("Enter the message : ")
    result = errorAnalyzer(error_message)
    print(result)
# Out:
# Critical

# %%
# String error message analyzer
def errorAnalyzer(error_message):
    error_message = error_message.lower()
    if "error" in error_message:
        return "Critical"
    elif "failed" in error_message:
        return "Moderate"
    elif "warning" in error_message:
        return "Informational"
    else:
        return "Unknown"

if __name__ == "__main__":
    f = open("text_files/error_log.txt", "r")
    for line in f:
        line = line.strip()
        print(line, "-", errorAnalyzer(line))
    f.close()
# Out:
# Disk read error detected - Critical
# Login warning: password attempts high - Informational

# %%
# Library book search using Functions

def bookSearch(book_name):
    library_books = ["Python Programming", "Data Science Handbook", "Artificial Intelligence Basics", "Machine Learning Guide", "Deep Learning with Python"]
    if book_name in library_books:
        print(f"{book_name} is available in the library.")
    elif book_name == "exit":
        print("Exiting program")
        exit() 
    else:
        print(f"{book_name} is not available in the library.")

if __name__ == "__main__":
    print(f"{'-'*5}Library book search using Functions{'-'*5}")
    print("Book Search options:\n 1. Start book search\n 2. Exit")
    user_input = int(input("Enter : "))
    book_name = ""
    if user_input == 1:
        while book_name.lower() != "exit":
            book_name = input("Enter the book name : ")
            bookSearch(book_name)   
    elif user_input == 2:
        print("Exiting program")
    else:
        print("Invalid input: Exiting program")
# Out:
# -----Library book search using Functions-----
# Book Search options:
#  1. Start book search
#  2. Exit
# Python Programming is available in the library.
# Art of the deal is not available in the library.
# Exiting program
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create CSV File for Student Data
import csv
def createCSV(file_name, data):
    with open(file_name, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(data)

def generateStudentData():
    data = [
        ["Name", "RegNo", "M1", "M2", "M3"],
        ["Asha","101",78,82,74],
        ["Ravi","102",65,70,60],
        ["Neha","103",90,88,92],
        ["Kiran","104",55,60,58],
        ["Arjun","105",80,75,85]
    ]
    return data
if __name__ == "__main__":
    file_name = "text_files/student_data.csv"
    student_data = generateStudentData()
    createCSV(file_name, student_data)

# %%
import csv

students = []
totals = []

def readFile(file_name):
    with open(file_name, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            marks = [int(row['M1']), int(row['M2']), int(row['M3'])]
            total = sum(marks)
            avg = total / len(marks)
            row['Total'] = total
            row['Average'] = avg
            students.append(row)
            totals.append(avg)

    class_avg = sum(totals) / len(totals)

    above_avg = []
    for s in students:
        if s["Average"] > class_avg:
            above_avg.append((s["Name"], s["RegNo"], s["Total"], s["Average"]))

    return above_avg

if __name__ == "__main__":
    file_name = "text_files/student_data.csv"
    result = readFile(file_name)
    print("Student Performance Data:", result)
# Out:
# Student Performance Data: [('Asha', '101', 234, 78.0), ('Neha', '103', 270, 90.0), ('Arjun', '105', 240, 80.0)]

# %%
# Hostel electricity bill processor

def processBill(units):
    for room,unit in units.items():
        if unit >=300:
            print(f"Room {room} has consumed {unit} units. High Usage : Bill is ₹{unit*8}")
        elif unit >=200:
            print(f"Room {room} has consumed {unit} units. Medium Usage : Bill is ₹{unit*6}")
        else:
            print(f"Room {room} has consumed {unit} units. Low Usage : Bill is ₹{unit*4}")

if __name__ == "__main__":
    hostel_data = {101:250,102:345,103:150} #The format is in room_number : units consumed
    result = processBill(hostel_data)
# Out:
# Room 101 has consumed 250 units. Medium Usage : Bill is ₹1500
# Room 102 has consumed 345 units. High Usage : Bill is ₹2760
# Room 103 has consumed 150 units. Low Usage : Bill is ₹600

# %%
# Code to generate the network log file 
import random

logs = [
"2026-03-15 10:21:34 ERROR from 192.168.1.10 connection failed",
"Random text abc123 !!!",
"2026-03-15 11:05:12 ERROR from 10.0.0.5 timeout",
"User login success 172.16.5.4",
"2026-03-15 12:45:09 ERROR from 8.8.8.8 packet loss detected",
"Noise data ###$$$",
"2026-03-15 14:10:55 ERROR from 192.168.0.2 system crash"
]

with open("text_files/network_log.txt","w") as f:
    for line in logs:
        f.write(line+"\n")

# %%
# Log file Sanitizer using Regex

import re

ip_pattern = re.compile(r'\b(?:\d{1,3}\.){3}\d{1,3}\b')
time_pattern = re.compile(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}')

with open("text_files/network_log.txt", "r") as file, open("text_files/network_log_cleaned.txt", "w") as file_op:
    for line in file:
        ip = re.findall(ip_pattern, line)
        time = re.findall(time_pattern, line)
        if ip and time:
            file_op.write(time[0] + " " + ip[0] + "\n")

# %%
# generate the student feedback summary report
with open("text_files/student_feedback.txt", "a+") as file:
    file.write("The course content was very informative and well-structured.\n")
    file.write("The instructor was engaging and explained concepts clearly.\n")
    file.write("I found the assignments to be challenging but rewarding.\n")
    file.write("Overall, I had a great learning experience in this course.\n")
    file.write("Needs improvement in the pace of the course.\n")
    file.write("The course did not cover enough real-world examples.\n")

# %%
# Student Feedback Summary generator

if __name__ == "__main__":
    f = open("text_files/student_feedback.txt", "r")
    key_summaries = {"good":["informative","engaging","rewarding","great"], 
                     "bad":["improvement","not enough"]}
    good_count, bad_count = 0,0
    for line in f:
        line = line.strip()
        for k,v in key_summaries.items():
            for word in v:
                if word in line.lower():
                    if k == "good":
                        good_count+=1
                    else:
                        bad_count+=1
                    break

    print(f"Good feedback count: {good_count}")
    print(f"Bad feedback count: {bad_count}")
# Out:
# Good feedback count: 4
# Bad feedback count: 1

# %%
# Custom function examples
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
    
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True


def gcd(a, b):
    while b != 0:
        a = b
        b = a % b
    return a

# %%
# using math_tools module
import math_tools

print("Factorial of 5:", math_tools.factorial(5))
print("Is 7 Prime?:", math_tools.is_prime(7))
print("GCD of 15 and 25:", math_tools.gcd(15, 25))

# %%
# File Organizer Automation tool

import shutil
import os
import time

if __name__ == "__main__":
    print("The Actual file organizer: Organizes files based on types")
    # file types
    file_types = {
        "Documents": [".pdf", ".docx", ".xlsx", ".txt"],
        "Images": [".png", ".jpeg", ".jpg"],
        "Programs": [".ipynb", ".py"]
    }
    source_folder = r"C:\Users\shash\Downloads\gene"

    for folder in file_types.keys():
        path = os.path.join(source_folder, folder)
        if not os.path.exists(path):
            os.makedirs(path)
    
    other_folders = os.path.join(source_folder, "Others")
    if not os.path.exists(other_folders):
        os.makedirs(other_folders)

    for filename in os.listdir(source_folder):
        file_path = os.path.join(source_folder, filename)
        if os.path.isfile(file_path):
            moved = False
            for folder, extensions in file_types.items():
                if filename.lower().endswith(tuple(extensions)):
                    shutil.move(file_path, os.path.join(source_folder, folder, filename))
                    moved = True
                    print(f"Moved {filename} to {folder}")
                    break
            if not moved:
                shutil.move(file_path, os.path.join(source_folder, "Others", filename))
                print(f"Moved {filename} to Others")
    
    print("File organization completed.")
# Out:
# The Actual file organizer: Organizes files based on types
# Moved 1. Linear_regression (1).pdf to Documents
# Moved 1. Linear_regression (2).pdf to Documents
# Moved 1. Linear_regression.pdf to Documents
# Moved 1. ShashwathKS_Python_for_automation_and_ai_agents_assignment1.pdf to Documents
# Moved Certificate (707).pdf to Documents
# Moved data_schema.sql to Others
# Moved policy_pdf.pdf to Documents
# Moved PUBLIC-POLICY.pdf to Documents
# Moved python_essentials_150_QA.pdf to Documents
# Moved python_secure_file_analyzer-main.zip to Others
# Moved review_source_schema.sql to Others
# Moved University_Policy.pdf to Documents
# Moved University_Policy_Chatbot-main.zip to Others
# File organization completed.

# %%
import streamlit as st
import PyPDF2
import os
from datetime import datetime

log_file = "streamlit_actions.txt"

def write_log(message):
    with open(log_file,"a") as file:
        file.write(f"{datetime.now()}-{message}\n")

st.title("PDF Processing Dashboard")
option = st.selectbox("Choose Operation", ["Merge PDFs", "Rename PDF"])

uploaded_files = st.file_uploader("Upload PDF files", type=["pdf"], accept_multiple_files=True)

if option == "Merge PDFs":
    if st.button("Merge"):
        if len(uploaded_files) >=2:
            merger = PyPDF2.PdfMerger()
            for pdf in uploaded_files:
                merger.append(pdf)
            
            output_file = "mergerd_file.pdf"
            with open(output_file, "wb") as file:
                merger.write(f)
            
            write_log("PDFs merged successfully")
            st.success("Merged Successfully")
        else:
            st.error("Please upload at least two PDFs")

if option == "Rename PDF":
    if uploaded_files and st.button("Rename"):
        new_name = st.text_input("Enter New file name excluding the PDF extension")
        if new_name:
            file = uploaded_files[0]
            output_path = f"{new_name}.pdf"
            with open(output_path, "wb") as f:
                f.write(file.read())
            
            write_log(f"PDF renamed successfully")
            st.success("Renamed successfully")
# Out:
# 2026-03-15 23:31:32.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 23:31:32.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Tk inter form validator

import tkinter as tk
from tkinter import messagebox

def submit():
    name = entry_name.get()
    email = entry_email.get()
    message = entry_message.get("1.0", tk.END).strip()

    if not name:
        messagebox.showerror("Error", "Name cannot be empty")
        entry_name.config(bg="red")
        return
    else:
        entry_name.config(bg="white")
    
    if not email:
        messagebox.showerror("Error", "Email cannot be empty")
        entry_email.config(bg="red")
        return
    else:
        entry_email.config(bg="white")
    
    if not message:
        messagebox.showerror("Error", "Message cannot be empty")
        entry_message.config(bg="red")
        return
    else:
        entry_message.config(bg="white")
    
    messagebox.showinfo("Success", "Form submitted successfully")

    entry_name.delete(0, tk.END)
    entry_email.delete(0, tk.END)
    entry_message.delete("1.0", tk.END)

root = tk.Tk()
root.title("Contact Form")
root.geometry("400x400")

label_name = tk.Label(root, text="Name:")
label_name.pack()
entry_name = tk.Entry(root, width=50)

label_email = tk.Label(root, text="Email:")
label_email.pack()
entry_email = tk.Entry(root, width=50)

label_message = tk.Label(root, text="Message:")
label_message.pack()
entry_message = tk.Text(root, width=50, height=10)

submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# %%
import tkinter as tk
from tkinter import messagebox

def submit():
    name = entry_name.get()
    email = entry_email.get()
    message = entry_message.get("1.0", tk.END).strip()

    if not name:
        messagebox.showerror("Error", "Name required!")
        entry_name.config(bg="pink")
        return
    else:
        entry_name.config(bg="white")

    if not email:
        messagebox.showerror("Error", "Email required!")
        entry_email.config(bg="pink")
        return
    else:
        entry_email.config(bg="white")

    if not message:
        messagebox.showerror("Error", "Message required!")
        entry_message.config(bg="pink")
        return
    else:
        entry_message.config(bg="white")

    with open("enquiries.txt", "a") as file:
        file.write(f"Name: {name}\n")
        file.write(f"Email: {email}\n")
        file.write(f"Message: {message}\n")
        file.write("-" * 30 + "\n")

    messagebox.showinfo("Success", "Enquiry Saved Successfully!")

    entry_name.delete(0, tk.END)
    entry_email.delete(0, tk.END)
    entry_message.delete("1.0", tk.END)

root = tk.Tk()
root.title("Student Enquiry Form")
root.geometry("400x400")

tk.Label(root, text="Name").pack()
entry_name = tk.Entry(root)
entry_name.pack()

tk.Label(root, text="Email").pack()
entry_email = tk.Entry(root)
entry_email.pack()

tk.Label(root, text="Message").pack()
entry_message = tk.Text(root, height=5)
entry_message.pack()

tk.Button(root, text="Submit", command=submit).pack(pady=10)

root.mainloop()
